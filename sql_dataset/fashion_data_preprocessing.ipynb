# %%
import pandas as pd
import numpy as np

# %%
import torch
import torchvision
from torchvision import transforms
import numpy as np
import cv2
from sklearn.cluster import KMeans
import pandas as pd
import requests
from PIL import Image
import io
import numpy as np
import torchvision
from torchvision.models.detection import maskrcnn_resnet50_fpn
from torchvision.models.detection import MaskRCNN_ResNet50_FPN_Weights

# %%
# 클래스 정의
class CSVDataLoader:
    def __init__(self, url):
        """
        CSV 파일을 다운로드하고 데이터프레임으로 로드하는 클래스
        Args:
            url (str): 다운로드할 CSV 파일의 URL
        """
        self.url = url
        self.file_name = "data.csv"

    def download_csv(self):
        """
        CSV 파일 다운로드
        """
        try:
            response = requests.get(self.url)
            response.raise_for_status()  # HTTP 에러가 발생하면 예외 발생
            with open(self.file_name, "wb") as file:
                file.write(response.content)
            print(f"CSV 파일이 '{self.file_name}' 이름으로 저장되었습니다.")
        except requests.exceptions.RequestException as e:
            print(f"파일 다운로드 중 에러 발생: {e}")

    def load_data(self, sample_size=None):
        """
        CSV 데이터를 Pandas DataFrame으로 로드하고 샘플 데이터를 반환
        Args:
            sample_size (int): 반환할 샘플 데이터 크기 (None이면 전체 데이터)
        Returns:
            pd.DataFrame: 로드된 데이터프레임 또는 샘플 데이터
        """
        try:
            data = pd.read_csv(self.file_name)
            print(f"데이터가 성공적으로 로드되었습니다. (총 {len(data)}개 행)")
            if sample_size:
                data = data.sample(n=sample_size, random_state=42)
            # 인덱스 리셋
            data.reset_index(drop=True, inplace=True)
            return data
        except Exception as e:
            print(f"데이터 로드 중 에러 발생: {e}")
            return pd.DataFrame()


    def url_to_pixels(self, url):
        """
        이미지 URL을 받아서 픽셀 값으로 변환
        Args:
            url (str): 이미지 URL
        Returns:
            np.ndarray: 이미지의 RGB 픽셀 값
        """
        try:
            response = requests.get(url)
            response.raise_for_status()
            image = Image.open(io.BytesIO(response.content))
            # 이미지를 RGB로 변환
            image = image.convert('RGB')
            return np.array(image)
        except requests.exceptions.RequestException as e:
            print(f"이미지 다운로드 중 에러 발생: {e}")
            return None

    def convert_images_in_dataframe(self, df, image_column):
        """
        데이터프레임의 이미지 URL 칼럼을 이미지 픽셀 값으로 변환
        Args:
            df (pd.DataFrame): 데이터프레임
            image_column (str): 이미지 URL이 들어있는 컬럼 이름
        Returns:
            pd.DataFrame: 이미지 URL을 픽셀 값으로 변환한 데이터프레임
        """
        df[image_column] = df[image_column].apply(lambda url: self.url_to_pixels(url) if pd.notna(url) else None)
        return df

class MaskRCNNProcessor:
    def __init__(self, device=None):
        """
        Mask R-CNN 모델 초기화 및 설정
        Args:
            device (str): 사용할 디바이스 (cuda 또는 cpu)
        """
        self.device = device if device else torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        self.model = self._get_mask_rcnn_model()

    def _get_mask_rcnn_model(self):
        """
        Mask R-CNN 모델 로드
        Returns:
        model: Mask R-CNN 모델
        """
        weights = MaskRCNN_ResNet50_FPN_Weights.COCO_V1  # COCO 데이터셋의 학습된 가중치를 사용
        model = maskrcnn_resnet50_fpn(weights=weights)
        model.eval()
        model.to(self.device)
        return model


    def preprocess_image(self, image_array):
        """
        이미지 전처리 함수
        Args:
            image_array (ndarray): 원본 이미지 배열
        Returns:
            torch.Tensor: 전처리된 이미지 텐서
        """
        transform = transforms.Compose([
            transforms.ToTensor(),
        ])
        image_tensor = transform(image_array).unsqueeze(0).to(self.device)
        return image_tensor

    def get_masks(self, image_tensor):
        """
        Mask R-CNN으로 객체 분할 수행
        Args:
            image_tensor (torch.Tensor): 전처리된 이미지 텐서
        Returns:
            dict: 객체 분할 결과
        """
        with torch.no_grad():
            predictions = self.model(image_tensor)
        return predictions

class ColorProcessor:
    def __init__(self, num_colors=1):
        """
        색상 처리 클래스 초기화
        Args:
            num_colors (int): 추출할 색상의 개수
        """
        self.num_colors = num_colors

    def generate_initial_mask(self, mask):
        """
        초기 마스크 생성
        Args:
            mask (torch.Tensor or ndarray): 분할 마스크
        Returns:
            ndarray: 초기 마스크
        """
        mask_np = mask.squeeze().cpu().numpy() if isinstance(mask, torch.Tensor) else mask.squeeze()
        thresholded_mask = (mask_np > 0.5).astype(np.uint8) * 255  # 0.5 이상의 값은 흰색, 나머지 영역은 검은색
        return thresholded_mask

    def extract_dominant_color(self, image, mask, num_colors=1):
        """
        마스크를 사용하여 이미지에서 대표 색상 추출
        Args:
            image (ndarray): 원본 이미지
            mask (ndarray): 마스크 이미지
            num_colors (int): 추출할 색상의 개수 (기본값 3)
        Returns:
            list: 대표 색상 리스트
            list: 각 색상의 비율 리스트
        """
        masked_image = cv2.bitwise_and(image, image, mask=mask)  # 마스크가 적용된 이미지
        pixels = masked_image[mask > 0].reshape(-1, 3)  # mask가 0이 아닌 부분만 고려

        # 유효한 픽셀만 사용 (너무 어두운 픽셀 제외)
        pixels = pixels[np.any(pixels > 10, axis=1)]

        # KMeans 클러스터링을 통해 대표 색상 추출
        if len(pixels) < num_colors:
            return [np.mean(pixels, axis=0)], [1.0]

        kmeans = KMeans(n_clusters=num_colors, random_state=0)
        kmeans.fit(pixels)

        # 각 클러스터가 차지하는 비율 계산
        unique, counts = np.unique(kmeans.labels_, return_counts=True)
        total_pixels = len(pixels)
        color_ratios = counts / total_pixels

        return kmeans.cluster_centers_, color_ratios

    def generate_heatmap(self, image, initial_mask):
        """
        히트맵 생성
        Args:
            image (ndarray): 원본 이미지
            initial_mask (ndarray): 초기 마스크
        Returns:
            ndarray: 히트맵 이미지
        """
        heatmap = cv2.applyColorMap(initial_mask, cv2.COLORMAP_JET)
        heatmap = np.float32(heatmap) / 255.0
        image = np.float32(image) / 255.0
        superimposed_image = cv2.addWeighted(image, 0.7, heatmap, 0.3, 0)
        return superimposed_image


class DatasetProcessor:
    def __init__(self, mask_rcnn_processor, color_processor):
        """
        데이터셋 처리 클래스 초기화
        Args:
            mask_rcnn_processor (MaskRCNNProcessor): Mask R-CNN 처리 객체
            color_processor (ColorProcessor): 색상 처리 객체
        """
        self.mask_rcnn_processor = mask_rcnn_processor
        self.color_processor = color_processor

    def process_image(self, image_array):
        """
        이미지를 처리하여 대표 색상, 비율, 마스크 및 히트맵을 생성
        Args:
            image_array (ndarray): 원본 이미지 배열
        Returns:
            tuple: 초기 마스크, 대표 색상, 비율, 히트맵
        """
        try:
            input_tensor = self.mask_rcnn_processor.preprocess_image(image_array)

            # Mask R-CNN을 사용하여 객체 분할
            predictions = self.mask_rcnn_processor.get_masks(input_tensor)
            masks = predictions[0]['masks']
            scores = predictions[0]['scores']
            labels = predictions[0]['labels']

            mask_np = None

            # 특정 객체 (예: 옷) 찾기
            for mask, score, label in zip(masks, scores, labels):
                if label.item() == 1:  # 옷을 포함하는 클래스의 인덱스 (예: COCO 데이터셋에서는 1이 사람으로 되어 있음)
                    mask_np = mask.squeeze().cpu().numpy()
                    break

            # 객체가 없으면 None 반환
            if mask_np is None:
                return None

            # 초기 마스크 생성
            initial_mask = self.color_processor.generate_initial_mask(mask_np)

            # 마스크만을 사용하여 대표 색상 및 비율 추출
            dominant_colors, color_ratios = self.color_processor.extract_dominant_color(image_array, initial_mask, num_colors=3)

            # 히트맵 생성
            heatmap_image = self.color_processor.generate_heatmap(image_array, initial_mask)
            return initial_mask, dominant_colors, color_ratios, heatmap_image

        except Exception as e:
            print(f"Error processing image: {e}")
            return None

    def label_personal_color(self, rgb):
        """
        주어진 RGB 값을 기반으로 퍼스널컬러를 라벨링
        Args:
            rgb (list or np.array): [R, G, B] 값 (0~255)
        Returns:
            str: 퍼스널컬러 라벨 (Spring Warm, Summer Cool, Autumn Warm, Winter Cool)
        """
        r, g, b = rgb

        # 색조: 따뜻한 색(웜) 또는 차가운 색(쿨) 판단
        if r >= g and r >= b:  # Red가 dominant
            tone = 'Warm'
        else:  # Blue or Green dominant
            tone = 'Cool'

        # 밝기: 밝음/어두움 판단 (YIQ 모델의 Y값 활용)
        brightness = 0.299 * r + 0.587 * g + 0.114 * b
        if brightness > 128:  # 밝으면
            lightness = 'Bright'
        else:  # 어두우면
            lightness = 'Dark'

        # 최종 라벨 결정
        if lightness == 'Bright' and tone == 'Warm':
            return 'Spring Warm'
        elif lightness == 'Bright' and tone == 'Cool':
            return 'Summer Cool'
        elif lightness == 'Dark' and tone == 'Warm':
            return 'Autumn Warm'
        else:
            return 'Winter Cool'

    def add_personal_color_labels(self, dataset):
        """
        데이터셋에 퍼스널컬러 라벨 추가
        Args:
            dataset (pd.DataFrame): 대표 색상이 포함된 데이터프레임
        Returns:
            pd.DataFrame: 퍼스널컬러 라벨이 추가된 데이터프레임
        """
        # 퍼스널컬러 라벨 추가
        dataset['personal_color'] = dataset['dominant_color'].apply(self.label_personal_color)
        return dataset

    def add_dominant_color_to_dataset(self, dataset):
        """
        데이터셋의 각 이미지에 대해 대표 색상 및 비율을 추가
        Args:
            dataset (pd.DataFrame): 이미지 데이터를 포함한 데이터프레임
        Returns:
            pd.DataFrame: 대표 색상 및 비율이 추가된 데이터프레임
        """
        dominant_color_list = []
        dominant_ratio_list = []
        valid_indices = []

        for idx, row in dataset.iterrows():
            image_array = row['이미지링크']  # 데이터프레임에서 이미지 데이터를 가져옴

            # 대표 색상 및 비율 추출
            result = self.process_image(image_array)

            # 객체가 감지되지 않으면 건너뛰기
            if result is None:
                continue

            _, dominant_colors, color_ratios, _ = result

            # 가장 높은 비율의 색상과 그 비율 선택
            max_ratio_idx = np.argmax(color_ratios)
            dominant_color = dominant_colors[max_ratio_idx]
            dominant_ratio = color_ratios[max_ratio_idx]

            # 유효한 값만 추가
            valid_indices.append(idx)
            dominant_color_list.append(dominant_color.astype(int).tolist())
            dominant_ratio_list.append(float(dominant_ratio))

        # 유효한 인덱스를 기반으로 데이터프레임 업데이트
        if valid_indices:
            dataset = dataset.loc[valid_indices].copy()
            dataset['dominant_color'] = dominant_color_list
            dataset['dominant_ratio'] = dominant_ratio_list
        else:
            print("No valid objects detected in the dataset.")
            dataset['dominant_color'] = []
            dataset['dominant_ratio'] = []

        # 퍼스널컬러 라벨 추가
        dataset = self.add_personal_color_labels(dataset)

        return dataset

# %% [markdown]
# # 깃허브 데이터 불러오기

# %%
if __name__ == "__main__":
    # 사용자 입력
    url = 'https://raw.githubusercontent.com/kieunseo/Fashion_x/refs/heads/main/data/file/clothes.csv?token=GHSAT0AAAAAAC5FDN7QFYUIDARLZT3YIT7WZ4JXSPQ'
    sample_size = 3000
    image_column = '이미지링크'
    # 클래스 사용
    loader = CSVDataLoader(url)
    loader.download_csv()

    # 데이터 로드 및 샘플링
    dataset = loader.load_data(sample_size=sample_size if sample_size > 0 else None)

    # 이미지 URL을 픽셀 값으로 변환
    dataset = loader.convert_images_in_dataframe(dataset, image_column)

    # 결과 출력
    print("로딩된 데이터셋:")
    print(dataset.head())
# Out:
# 파일 다운로드 중 에러 발생: 404 Client Error: Not Found for url: https://raw.githubusercontent.com/kieunseo/Fashion_x/refs/heads/main/data/file/clothes.csv?token=GHSAT0AAAAAAC5FDN7QFYUIDARLZT3YIT7WZ4JXSPQ
# 데이터가 성공적으로 로드되었습니다. (총 7120개 행)
# 이미지 다운로드 중 에러 발생: 404 Client Error: Not Found for url: https://image.msscdn.net/thumbnails/images/goods_img/20240428/4092312/4092312_17322578812645_big.jpg?w=780
# 이미지 다운로드 중 에러 발생: 404 Client Error: Not Found for url: https://image.msscdn.net/thumbnails/images/goods_img/20240719/4261057/4261057_17325227511671_big.jpg?w=780
# 이미지 다운로드 중 에러 발생: 404 Client Error: Not Found for url: https://image.msscdn.net/thumbnails/images/goods_img/20240620/4209355/4209355_17308602073825_big.jpg?w=780
# 이미지 다운로드 중 에러 발생: 404 Client Error: Not Found for url: https://image.msscdn.net/thumbnails/images/goods_img/20241022/4542610/4542610_17297325883588_big.jpg?w=780
# 이미지 다운로드 중 에러 발생: 404 Client Error: Not Found for url: https://image.msscdn.net/thumbnails/images/goods_img/20241107/4595116/4595116_17309457867091_big.jpg?w=780
# 이미지 다운로드 중 에러 발생: 404 Client Error: Not Found for url: https://image.msscdn.net/thumbnails/images/goods_img/20240819/4341019/4341019_17322588104482_big.jpg?w=780
# 이미지 다운로드 중 에러 발생: 404 Client Error: Not Found for url: https://image.msscdn.net/thumbnails/images/goods_img/20190410/1010295/1010295_2_big.jpg?w=780
# 이미지 다운로드 중 에러 발생: 404 Client Error: Not Found for url: https://image.msscdn.net/thumbnails/images/goods_img/20240620/4209351/4209351_17308711442041_big.jpg?w=780
# 이미지 다운로드 중 에러 발생: 404 Client Error: Not Found for url: https://image.msscdn.net/thumbnails/images/goods_img/20240821/4355569/4355569_17313014317052_big.jpg?w=780
# 이미지 다운로드 중 에러 발생: 404 Client Error: Not Found for url: https://image.msscdn.net/thumbnails/images/goods_img/20240924/4457592/4457592_17282720977624_big.jpg?w=780
# 이미지 다운로드 중 에러 발생: 404 Client Error: Not Found for url: https://image.msscdn.net/thumbnails/images/goods_img/20240415/4052945/4052945_17198808164928_big.jpg?w=780
# 이미지 다운로드 중 에러 발생: 404 Client Error: Not Found for url: https://image.msscdn.net/thumbnails/images/goods_img/20241004/4486569/4486569_17290418138774_big.jpg?w=780
# 이미지 다운로드 중 에러 발생: 404 Client Error: Not Found for url: https://image.msscdn.net/thumbnails/images/goods_img/20240423/4079105/4079105_17211846555761_big.jpg?w=780
# 이미지 다운로드 중 에러 발생: 404 Client Error: Not Found for url: https://image.msscdn.net/thumbnails/images/goods_img/20240621/4213384/4213384_17327591910352_big.jpg?w=780
# 이미지 다운로드 중 에러 발생: 404 Client Error: Not Found for url: https://image.msscdn.net/thumbnails/images/goods_img/20230712/3405559/3405559_17273157528437_big.jpg?w=780
# 이미지 다운로드 중 에러 발생: 404 Client Error: Not Found for url: https://image.msscdn.net/thumbnails/images/goods_img/20240719/4261056/4261056_17325227509340_big.jpg?w=780
# 이미지 다운로드 중 에러 발생: 404 Client Error: Not Found for url: https://image.msscdn.net/thumbnails/images/goods_img/20240411/4044505/4044505_17128142939281_big.jpg?w=780
# 로딩된 데이터셋:
#    대분류         소분류  성별   계절    브랜드명                            상품명  \
# 0   바지  트레이닝/조거 팬츠  남성   여름  엔피스튜디오               코튼 와이드 스웨트 팬츠 블랙
# 1   상의     셔츠/블라우스  남성    봄  필루미네이트  [유튜버 니들 착용] 오버핏 포레스트 체크 셔츠-블랙
# 2  아우터       무스탕/퍼  남성  NaN     엘무드   A2 에비에이터 카우 하이드 무스탕 자켓 탠 브라운
# 3  아우터     플리스/뽀글이  여성  NaN    피도디도        Fleece Zip Hoodie Black
# 4  스커트       미니스커트  여성   가을  로맨틱크라운              샤이닝 로고 플리츠 스커트_블랙
#
#                                                이미지링크
# 0  [[[227, 228, 222], [227, 228, 222], [227, 228,...
# 1  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 2  [[[90, 89, 85], [87, 86, 82], [87, 86, 82], [8...
# 3  [[[241, 241, 241], [241, 241, 241], [241, 241,...
# 4  [[[206, 200, 204], [206, 200, 204], [205, 199,...

# %%
dataset.shape
# Out:
# (3000, 7)

# %%
data = pd.read_csv("data_original.csv")
data.head()
# Out:
#   대분류      소분류  성별 계절   브랜드명                           상품명  \
# 0  상의  맨투맨/스웨트  남성  봄   엠더바스   reach out 오버핏 스웨트셔츠 -메란지그레이
# 1  상의  맨투맨/스웨트  남성  봄  넷소셜클럽  SMALL CURLY LOGO MTM (BLACK)
# 2  상의  맨투맨/스웨트  남성  봄  세인트크루     체스트 화이트캣 스웨트셔츠 CCS-809 블랙
# 3  상의  맨투맨/스웨트  남성  봄  세인트크루    체스트 블랙아치 스웨트셔츠 CCS-809 그레이
# 4  상의  맨투맨/스웨트  남성  봄    지크립           NEW YORKLIP 특양면 맨투맨
#
#                                                이미지링크
# 0  https://image.msscdn.net/thumbnails/images/goo...
# 1  https://image.msscdn.net/thumbnails/images/goo...
# 2  https://image.msscdn.net/thumbnails/images/goo...
# 3  https://image.msscdn.net/thumbnails/images/goo...
# 4  https://image.msscdn.net/thumbnails/images/goo...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7120 entries, 0 to 7119
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   대분류     7120 non-null   object
#  1   소분류     7120 non-null   object
#  2   성별      7120 non-null   object
#  3   계절      6789 non-null   object
#  4   브랜드명    7120 non-null   object
#  5   상품명     7120 non-null   object
#  6   이미지링크   7120 non-null   object
# dtypes: object(7)
# memory usage: 389.5+ KB

# %%
if __name__ == "__main__":
    # 클래스 초기화
    device = "cuda" if torch.cuda.is_available() else "cpu"
    mask_rcnn_processor = MaskRCNNProcessor(device)
    color_processor = ColorProcessor(num_colors=1)
    dataset_processor = DatasetProcessor(mask_rcnn_processor, color_processor)

    # 데이터셋 처리
    processed_dataset = dataset_processor.add_dominant_color_to_dataset(dataset)

    # 결과 출력
    print(processed_dataset)

    # 각 행의 결과 시각화 (예시)
    for idx, row in processed_dataset.iterrows():
        print(f"이미지 {idx}: Dominant Color: {row['dominant_color']}, Ratio: {row['dominant_ratio']}")
# Out:
# Error processing image: pic should be PIL Image or ndarray. Got <class 'NoneType'>
# Error processing image: pic should be PIL Image or ndarray. Got <class 'NoneType'>
# Error processing image: pic should be PIL Image or ndarray. Got <class 'NoneType'>
# Error processing image: pic should be PIL Image or ndarray. Got <class 'NoneType'>
# Error processing image: pic should be PIL Image or ndarray. Got <class 'NoneType'>
# Error processing image: pic should be PIL Image or ndarray. Got <class 'NoneType'>
# Error processing image: pic should be PIL Image or ndarray. Got <class 'NoneType'>
# Error processing image: pic should be PIL Image or ndarray. Got <class 'NoneType'>
# Error processing image: pic should be PIL Image or ndarray. Got <class 'NoneType'>
# Error processing image: pic should be PIL Image or ndarray. Got <class 'NoneType'>
# Error processing image: pic should be PIL Image or ndarray. Got <class 'NoneType'>
# Error processing image: pic should be PIL Image or ndarray. Got <class 'NoneType'>
# Error processing image: pic should be PIL Image or ndarray. Got <class 'NoneType'>
# Error processing image: pic should be PIL Image or ndarray. Got <class 'NoneType'>
# Error processing image: pic should be PIL Image or ndarray. Got <class 'NoneType'>
# Error processing image: pic should be PIL Image or ndarray. Got <class 'NoneType'>
# Error processing image: pic should be PIL Image or ndarray. Got <class 'NoneType'>
#        대분류         소분류  성별   계절       브랜드명  \
# 0       바지  트레이닝/조거 팬츠  남성   여름     엔피스튜디오
# 1       상의     셔츠/블라우스  남성    봄     필루미네이트
# 2      아우터       무스탕/퍼  남성  NaN        엘무드
# 3      아우터     플리스/뽀글이  여성  NaN       피도디도
# 4      스커트       미니스커트  여성   가을     로맨틱크라운
# ...    ...         ...  ..  ...        ...
# 2994  패션소품        액세서리  여성  사계절         할렌
# 2996    상의    피케/카라티셔츠  남성   여름  디스커스 애슬레틱
# 2997   아우터  레더/라이더스 재킷  남성   겨울      리우 옴므
# 2998    상의     셔츠/블라우스  여성   가을      스테이피플
# 2999   아우터         카디건  남성   가을        빈트릴
#
#                                                상품명  \
# 0                                 코튼 와이드 스웨트 팬츠 블랙
# 1                    [유튜버 니들 착용] 오버핏 포레스트 체크 셔츠-블랙
# 2                     A2 에비에이터 카우 하이드 무스탕 자켓 탠 브라운
# 3                          Fleece Zip Hoodie Black
# 4                                샤이닝 로고 플리츠 스커트_블랙
# ...                                            ...
# 2994                basic wool gloves (G001_black)
# 2996  DA × OAM Emblem Terry Tennis Shirt Off White
# 2997                               비건 레더 바시티 자켓_블랙
# 2998                 CHINA NECK BOXY SHIRT (CREAM)
# 2999                            레터링 아트 오버핏 가디건(블랙)
#
#                                                   이미지링크   dominant_color  \
# 0     [[[227, 228, 222], [227, 228, 222], [227, 228,...     [27, 31, 33]
# 1     [[[255, 255, 255], [255, 255, 255], [255, 255,...     [35, 35, 35]
# 2     [[[90, 89, 85], [87, 86, 82], [87, 86, 82], [8...     [41, 33, 29]
# 3     [[[241, 241, 241], [241, 241, 241], [241, 241,...     [21, 22, 27]
# 4     [[[206, 200, 204], [206, 200, 204], [205, 199,...  [169, 136, 110]
# ...                                                 ...              ...
# 2994  [[[240, 240, 240], [240, 240, 240], [240, 240,...     [21, 20, 24]
# 2996  [[[70, 70, 68], [65, 65, 63], [63, 63, 61], [6...  [207, 200, 202]
# 2997  [[[235, 235, 235], [235, 235, 235], [235, 235,...     [25, 25, 25]
# 2998  [[[255, 255, 255], [255, 255, 255], [255, 255,...  [232, 224, 215]
# 2999  [[[255, 255, 255], [255, 255, 255], [255, 255,...     [33, 30, 31]
#
#       dominant_ratio personal_color
# 0           0.924865    Winter Cool
# 1           0.592077    Autumn Warm
# 2           0.522527    Autumn Warm
# 3           0.602018    Winter Cool
# 4           0.613097    Spring Warm
# ...              ...            ...
# 2994        0.611816    Winter Cool
# 2996        0.575166    Spring Warm
# 2997        0.487765    Autumn Warm
# 2998        0.513359    Spring Warm
# 2999        0.957249    Autumn Warm
#
# [2396 rows x 10 columns]
# 이미지 0: Dominant Color: [27, 31, 33], Ratio: 0.9248654798949415
# 이미지 1: Dominant Color: [35, 35, 35], Ratio: 0.5920769254778859
# 이미지 2: Dominant Color: [41, 33, 29], Ratio: 0.5225273892372356
# 이미지 3: Dominant Color: [21, 22, 27], Ratio: 0.6020180748781296
# 이미지 4: Dominant Color: [169, 136, 110], Ratio: 0.6130967561725021
# 이미지 6: Dominant Color: [219, 214, 201], Ratio: 0.5670081332366469
# 이미지 7: Dominant Color: [211, 205, 188], Ratio: 0.7867562680758987
# 이미지 8: Dominant Color: [37, 37, 36], Ratio: 0.8886740117021802
# 이미지 9: Dominant Color: [17, 26, 29], Ratio: 0.7803436363010319
# 이미지 10: Dominant Color: [65, 66, 53], Ratio: 0.56287245730266
# 이미지 11: Dominant Color: [15, 17, 18], Ratio: 0.48255554424352537
# 이미지 15: Dominant Color: [252, 240, 220], Ratio: 0.7398535013942247
# 이미지 16: Dominant Color: [17, 17, 17], Ratio: 0.4756321678647033
# 이미지 17: Dominant Color: [66, 61, 60], Ratio: 0.5027834660951748
# 이미지 18: Dominant Color: [78, 75, 74], Ratio: 0.44345542759650247
# 이미지 19: Dominant Color: [238, 218, 220], Ratio: 0.8695558456177327
# 이미지 20: Dominant Color: [20, 20, 21], Ratio: 0.4878356418057104
# 이미지 21: Dominant Color: [17, 24, 31], Ratio: 0.4895289925076748
# 이미지 22: Dominant Color: [238, 216, 197], Ratio: 0.5492705028866851
# 이미지 23: Dominant Color: [226, 214, 191], Ratio: 0.49367409532761136
# 이미지 24: Dominant Color: [145, 139, 139], Ratio: 0.6335316950370034
# 이미지 25: Dominant Color: [40, 34, 31], Ratio: 0.6267600450662122
# 이미지 26: Dominant Color: [77, 77, 81], Ratio: 0.9144175260275325
# 이미지 27: Dominant Color: [140, 139, 140], Ratio: 0.37000433612247613
# 이미지 28: Dominant Color: [102, 92, 87], Ratio: 0.37681206980006726
# 이미지 29: Dominant Color: [35, 40, 32], Ratio: 0.6215178146351507
# 이미지 30: Dominant Color: [21, 21, 24], Ratio: 0.9037080045682485
# 이미지 31: Dominant Color: [46, 50, 64], Ratio: 0.40463026031895827
# 이미지 32: Dominant Color: [103, 103, 101], Ratio: 0.5254507768219088
# 이미지 33: Dominant Color: [22, 27, 29], Ratio: 0.8313372314110263
# 이미지 34: Dominant Color: [18, 18, 19], Ratio: 0.7013194255244619
# 이미지 35: Dominant Color: [25, 23, 19], Ratio: 0.7110219441899326
# 이미지 36: Dominant Color: [34, 33, 33], Ratio: 0.7370259373450335
# 이미지 37: Dominant Color: [52, 13, 12], Ratio: 0.4838649407670795
# 이미지 38: Dominant Color: [253, 253, 253], Ratio: 0.610650747680123
# 이미지 39: Dominant Color: [36, 59, 84], Ratio: 0.5927273765763267
# 이미지 40: Dominant Color: [56, 45, 37], Ratio: 0.5768952342650312
# 이미지 44: Dominant Color: [36, 33, 29], Ratio: 0.926161191749427
# 이미지 48: Dominant Color: [19, 18, 18], Ratio: 0.8366777807324374
# 이미지 50: Dominant Color: [206, 201, 190], Ratio: 0.5652073658149809
# 이미지 51: Dominant Color: [26, 26, 27], Ratio: 0.650387185648497
# 이미지 52: Dominant Color: [30, 34, 37], Ratio: 0.46159411710538434
# 이미지 53: Dominant Color: [30, 27, 31], Ratio: 0.5913243827860264
# 이미지 54: Dominant Color: [205, 206, 224], Ratio: 0.47475913161601935
# 이미지 55: Dominant Color: [166, 141, 103], Ratio: 0.9073461821232528
# 이미지 56: Dominant Color: [40, 39, 52], Ratio: 0.9065750242013553
# 이미지 57: Dominant Color: [26, 68, 109], Ratio: 0.7409633536034449
# 이미지 59: Dominant Color: [230, 221, 212], Ratio: 0.5547948118222411
# 이미지 60: Dominant Color: [18, 26, 40], Ratio: 0.7150678317212591
# 이미지 61: Dominant Color: [238, 236, 225], Ratio: 0.38844377415402015
# 이미지 62: Dominant Color: [209, 198, 184], Ratio: 0.43276731991157896
# 이미지 63: Dominant Color: [41, 44, 46], Ratio: 0.8744617773699442
# 이미지 64: Dominant Color: [221, 222, 226], Ratio: 0.6525369691209858
# 이미지 66: Dominant Color: [30, 29, 31], Ratio: 0.8724572928991012
# 이미지 67: Dominant Color: [39, 38, 36], Ratio: 0.626023850671752
# 이미지 68: Dominant Color: [27, 24, 18], Ratio: 0.6179586819048413
# 이미지 69: Dominant Color: [132, 137, 136], Ratio: 0.3865977148895992
# 이미지 70: Dominant Color: [29, 29, 33], Ratio: 0.67175653480888
# 이미지 71: Dominant Color: [215, 199, 195], Ratio: 0.5497921894604768
# 이미지 72: Dominant Color: [222, 216, 222], Ratio: 0.7803898565111452
# 이미지 73: Dominant Color: [182, 178, 177], Ratio: 0.5630456387959745
# 이미지 74: Dominant Color: [27, 23, 29], Ratio: 0.46734070929737886
# 이미지 76: Dominant Color: [218, 218, 220], Ratio: 0.8032770658336652
# 이미지 77: Dominant Color: [43, 50, 66], Ratio: 0.5161257955781179
# 이미지 78: Dominant Color: [41, 41, 41], Ratio: 0.5931460724116884
# 이미지 79: Dominant Color: [38, 28, 22], Ratio: 0.7071928297385305
# 이미지 80: Dominant Color: [118, 87, 64], Ratio: 0.48159638110199493
# 이미지 81: Dominant Color: [150, 117, 96], Ratio: 0.3883107974080931
# 이미지 82: Dominant Color: [54, 54, 54], Ratio: 0.9658219948383574
# 이미지 83: Dominant Color: [100, 83, 66], Ratio: 0.45375671453875766
# 이미지 85: Dominant Color: [18, 18, 23], Ratio: 0.7124676814866143
# 이미지 86: Dominant Color: [31, 29, 34], Ratio: 0.4772753764477742
# 이미지 87: Dominant Color: [147, 71, 32], Ratio: 0.8066198746463474
# 이미지 88: Dominant Color: [222, 211, 210], Ratio: 0.41297733371197415
# 이미지 90: Dominant Color: [38, 35, 34], Ratio: 0.7412463119955607
# 이미지 91: Dominant Color: [80, 121, 192], Ratio: 0.8246174596256464
# 이미지 92: Dominant Color: [37, 31, 32], Ratio: 0.622806189847141
# 이미지 93: Dominant Color: [33, 34, 44], Ratio: 0.5485237527016212
# 이미지 95: Dominant Color: [63, 52, 57], Ratio: 0.7567939717561597
# 이미지 96: Dominant Color: [178, 178, 177], Ratio: 0.4567272023483113
# 이미지 97: Dominant Color: [18, 17, 21], Ratio: 0.685923405174742
# 이미지 98: Dominant Color: [27, 30, 46], Ratio: 0.8715133321166388
# 이미지 99: Dominant Color: [195, 188, 181], Ratio: 0.5405075201574963
# 이미지 100: Dominant Color: [213, 212, 207], Ratio: 0.7607033577420215
# 이미지 101: Dominant Color: [243, 238, 232], Ratio: 0.8485905197153966
# 이미지 104: Dominant Color: [178, 174, 168], Ratio: 0.7687376312499772
# 이미지 105: Dominant Color: [235, 238, 244], Ratio: 0.9030492900081326
# 이미지 106: Dominant Color: [34, 35, 41], Ratio: 0.7187942519320036
# 이미지 107: Dominant Color: [9, 30, 52], Ratio: 0.7413898528512551
# 이미지 108: Dominant Color: [212, 218, 223], Ratio: 0.5272604792072356
# 이미지 109: Dominant Color: [42, 33, 36], Ratio: 0.41127803318350953
# 이미지 111: Dominant Color: [50, 30, 18], Ratio: 0.5346413618165704
# 이미지 113: Dominant Color: [186, 176, 156], Ratio: 0.6944376472394551
# 이미지 114: Dominant Color: [28, 28, 27], Ratio: 0.9701078184518045
# 이미지 117: Dominant Color: [157, 123, 102], Ratio: 0.707320475168347
# 이미지 118: Dominant Color: [20, 19, 18], Ratio: 0.4372948510406139
# 이미지 119: Dominant Color: [55, 38, 35], Ratio: 0.6009442166728787
# 이미지 120: Dominant Color: [159, 124, 77], Ratio: 0.7396069272610742
# 이미지 121: Dominant Color: [25, 32, 35], Ratio: 0.7359996929336353
# 이미지 123: Dominant Color: [189, 185, 199], Ratio: 0.34777973645435545
# 이미지 124: Dominant Color: [215, 207, 211], Ratio: 0.47776829432640044
# 이미지 125: Dominant Color: [241, 166, 193], Ratio: 0.6741101886322217
# 이미지 126: Dominant Color: [32, 23, 22], Ratio: 0.44239193642178715
# 이미지 127: Dominant Color: [225, 221, 216], Ratio: 0.5208849513226719
# 이미지 129: Dominant Color: [44, 44, 42], Ratio: 0.7584706042513468
# 이미지 130: Dominant Color: [80, 75, 70], Ratio: 0.4436891770524477
# 이미지 131: Dominant Color: [186, 140, 126], Ratio: 0.4156790855663989
# 이미지 132: Dominant Color: [59, 57, 59], Ratio: 0.5228008694494966
# 이미지 134: Dominant Color: [37, 40, 55], Ratio: 0.7214821069310233
# 이미지 135: Dominant Color: [226, 224, 228], Ratio: 0.6121840357869572
# 이미지 136: Dominant Color: [30, 28, 31], Ratio: 0.974209124898252
# 이미지 137: Dominant Color: [25, 22, 19], Ratio: 0.6991375558565903
# 이미지 138: Dominant Color: [23, 19, 16], Ratio: 0.401488579005903
# 이미지 139: Dominant Color: [35, 35, 35], Ratio: 0.9730381529137211
# 이미지 140: Dominant Color: [229, 187, 168], Ratio: 0.4531938705690781
# 이미지 141: Dominant Color: [18, 29, 36], Ratio: 0.780996022231535
# 이미지 142: Dominant Color: [205, 189, 161], Ratio: 0.6062759847002085
# 이미지 145: Dominant Color: [20, 23, 32], Ratio: 0.4819350337602138
# 이미지 146: Dominant Color: [52, 55, 61], Ratio: 0.4550012490522542
# 이미지 148: Dominant Color: [57, 57, 59], Ratio: 0.6706134610794215
# 이미지 149: Dominant Color: [54, 50, 48], Ratio: 0.41103183071041166
# 이미지 150: Dominant Color: [213, 175, 146], Ratio: 0.3644620039927511
# 이미지 151: Dominant Color: [57, 47, 48], Ratio: 0.471754226244667
# 이미지 152: Dominant Color: [229, 221, 222], Ratio: 0.601930695864875
# 이미지 153: Dominant Color: [20, 23, 30], Ratio: 0.7467974694262662
# 이미지 155: Dominant Color: [59, 28, 18], Ratio: 0.4916538350902723
# 이미지 156: Dominant Color: [23, 25, 31], Ratio: 0.7199297263220351
# 이미지 157: Dominant Color: [20, 20, 16], Ratio: 0.9657079916778852
# 이미지 159: Dominant Color: [109, 109, 112], Ratio: 0.49359797355911034
# 이미지 160: Dominant Color: [35, 41, 44], Ratio: 0.40259044754733847
# 이미지 161: Dominant Color: [30, 37, 36], Ratio: 0.3542290105210497
# 이미지 162: Dominant Color: [21, 23, 25], Ratio: 0.4835124755016127
# 이미지 165: Dominant Color: [197, 191, 188], Ratio: 0.5428539420618393
# 이미지 166: Dominant Color: [55, 55, 47], Ratio: 0.38744336009763924
# 이미지 167: Dominant Color: [156, 171, 151], Ratio: 0.5921801991938687
# 이미지 169: Dominant Color: [47, 48, 51], Ratio: 0.5061437463028214
# 이미지 170: Dominant Color: [190, 189, 191], Ratio: 0.674632759964694
# 이미지 171: Dominant Color: [37, 37, 37], Ratio: 0.7297027759653283
# 이미지 172: Dominant Color: [19, 21, 26], Ratio: 0.5642025173774188
# 이미지 173: Dominant Color: [77, 74, 72], Ratio: 0.441911897592668
# 이미지 174: Dominant Color: [39, 31, 28], Ratio: 0.5775414105140493
# 이미지 175: Dominant Color: [241, 241, 240], Ratio: 0.3874821426859318
# 이미지 176: Dominant Color: [67, 55, 62], Ratio: 0.4903403505698463
# 이미지 177: Dominant Color: [56, 56, 48], Ratio: 0.7782280018427775
# 이미지 178: Dominant Color: [207, 193, 175], Ratio: 0.49388890198204144
# 이미지 179: Dominant Color: [68, 14, 19], Ratio: 0.5829057849325381
# 이미지 181: Dominant Color: [195, 198, 206], Ratio: 0.5651146593416607
# 이미지 182: Dominant Color: [30, 28, 32], Ratio: 0.9606196259945605
# 이미지 183: Dominant Color: [228, 217, 199], Ratio: 0.6596017859695813
# 이미지 185: Dominant Color: [60, 61, 58], Ratio: 0.5457829767054191
# 이미지 186: Dominant Color: [34, 33, 41], Ratio: 0.6315416336803299
# 이미지 187: Dominant Color: [235, 235, 241], Ratio: 0.8526680370568525
# 이미지 188: Dominant Color: [57, 51, 49], Ratio: 0.5497635892711249
# 이미지 190: Dominant Color: [157, 146, 143], Ratio: 0.41885618379294787
# 이미지 191: Dominant Color: [28, 28, 28], Ratio: 0.6686508212452887
# 이미지 192: Dominant Color: [26, 25, 32], Ratio: 0.9456948557135237
# 이미지 194: Dominant Color: [211, 205, 191], Ratio: 0.7678909471976202
# 이미지 195: Dominant Color: [63, 64, 70], Ratio: 0.8093842807902194
# 이미지 196: Dominant Color: [167, 184, 160], Ratio: 0.48083156819089257
# 이미지 197: Dominant Color: [21, 26, 32], Ratio: 0.8374949545562097
# 이미지 198: Dominant Color: [122, 122, 118], Ratio: 0.5402847586838319
# 이미지 200: Dominant Color: [32, 32, 32], Ratio: 0.9276147246436616
# 이미지 202: Dominant Color: [22, 22, 23], Ratio: 0.8191358024691358
# 이미지 203: Dominant Color: [24, 25, 29], Ratio: 0.6856195853555805
# 이미지 204: Dominant Color: [40, 34, 39], Ratio: 0.5942277525192098
# 이미지 205: Dominant Color: [47, 43, 45], Ratio: 0.5326504788098213
# 이미지 206: Dominant Color: [228, 224, 228], Ratio: 0.7800882597215852
# 이미지 207: Dominant Color: [24, 30, 30], Ratio: 0.7305790095906989
# 이미지 208: Dominant Color: [141, 121, 110], Ratio: 0.4657407007387566
# 이미지 210: Dominant Color: [51, 42, 39], Ratio: 0.5456176487952716
# 이미지 211: Dominant Color: [54, 46, 41], Ratio: 0.37837126392711834
# 이미지 212: Dominant Color: [27, 28, 34], Ratio: 0.5642376635936893
# 이미지 213: Dominant Color: [64, 56, 59], Ratio: 0.45888493289008664
# 이미지 214: Dominant Color: [27, 29, 44], Ratio: 0.8368393747517262
# 이미지 215: Dominant Color: [221, 214, 199], Ratio: 0.7849100379864886
# 이미지 217: Dominant Color: [230, 228, 218], Ratio: 0.41601038685000724
# 이미지 218: Dominant Color: [133, 133, 145], Ratio: 0.6285216699692143
# 이미지 219: Dominant Color: [183, 164, 147], Ratio: 0.47071853052404106
# 이미지 220: Dominant Color: [184, 185, 190], Ratio: 0.5891482234391849
# 이미지 222: Dominant Color: [50, 46, 46], Ratio: 0.5713686070109354
# 이미지 223: Dominant Color: [227, 223, 222], Ratio: 0.5055830181159674
# 이미지 224: Dominant Color: [22, 30, 33], Ratio: 0.49955951590075387
# 이미지 225: Dominant Color: [197, 197, 197], Ratio: 0.8196862294470041
# 이미지 226: Dominant Color: [31, 35, 49], Ratio: 0.7353497567396181
# 이미지 227: Dominant Color: [24, 22, 22], Ratio: 0.7480686395026934
# 이미지 228: Dominant Color: [189, 194, 193], Ratio: 0.8232964299042169
# 이미지 229: Dominant Color: [33, 36, 45], Ratio: 0.5871098120164505
# 이미지 230: Dominant Color: [29, 29, 35], Ratio: 0.5198144059800481
# 이미지 231: Dominant Color: [55, 55, 57], Ratio: 0.5050157817431795
# 이미지 233: Dominant Color: [28, 28, 29], Ratio: 0.7442790325098941
# 이미지 234: Dominant Color: [27, 28, 32], Ratio: 0.8563284308538779
# 이미지 236: Dominant Color: [18, 20, 26], Ratio: 0.7980343344130033
# 이미지 237: Dominant Color: [160, 160, 158], Ratio: 0.4828575016133601
# 이미지 238: Dominant Color: [75, 76, 79], Ratio: 0.5704557657829834
# 이미지 239: Dominant Color: [221, 195, 203], Ratio: 0.6404062761038781
# 이미지 240: Dominant Color: [15, 15, 21], Ratio: 0.7927674330855797
# 이미지 241: Dominant Color: [88, 75, 80], Ratio: 0.5334313830055967
# 이미지 242: Dominant Color: [227, 191, 196], Ratio: 0.6328118592635118
# 이미지 243: Dominant Color: [49, 40, 35], Ratio: 0.4289158998080803
# 이미지 244: Dominant Color: [202, 174, 159], Ratio: 0.8906919902231839
# 이미지 245: Dominant Color: [226, 224, 240], Ratio: 0.7051948759880077
# 이미지 246: Dominant Color: [34, 33, 34], Ratio: 0.5115661609102493
# 이미지 247: Dominant Color: [211, 208, 206], Ratio: 0.5032574005211841
# 이미지 248: Dominant Color: [226, 202, 168], Ratio: 0.4298048241102654
# 이미지 250: Dominant Color: [134, 136, 137], Ratio: 0.6661281436590777
# 이미지 252: Dominant Color: [30, 29, 32], Ratio: 0.9662847904619555
# 이미지 255: Dominant Color: [221, 177, 168], Ratio: 0.6606046462972053
# 이미지 257: Dominant Color: [40, 41, 48], Ratio: 0.4838018431200776
# 이미지 258: Dominant Color: [179, 165, 164], Ratio: 0.6898520721837694
# 이미지 260: Dominant Color: [202, 178, 170], Ratio: 0.365182573358035
# 이미지 261: Dominant Color: [220, 202, 182], Ratio: 0.5236832182652676
# 이미지 262: Dominant Color: [21, 21, 27], Ratio: 0.5298127261867116
# 이미지 264: Dominant Color: [40, 34, 35], Ratio: 0.5444914696531411
# 이미지 265: Dominant Color: [35, 33, 34], Ratio: 0.7596239576231185
# 이미지 266: Dominant Color: [210, 160, 168], Ratio: 0.4452077321666822
# 이미지 270: Dominant Color: [54, 17, 21], Ratio: 0.4814938481241227
# 이미지 271: Dominant Color: [81, 92, 107], Ratio: 0.4779108556730035
# 이미지 272: Dominant Color: [39, 37, 42], Ratio: 0.6144313616844438
# 이미지 273: Dominant Color: [14, 19, 21], Ratio: 0.700728435301575
# 이미지 274: Dominant Color: [44, 43, 53], Ratio: 0.8157901894387554
# 이미지 275: Dominant Color: [42, 42, 44], Ratio: 0.9271036478148278
# 이미지 276: Dominant Color: [183, 156, 146], Ratio: 0.5375636633860765
# 이미지 277: Dominant Color: [202, 205, 202], Ratio: 0.6354430379746835
# 이미지 278: Dominant Color: [30, 30, 27], Ratio: 0.6435167827044986
# 이미지 279: Dominant Color: [238, 238, 242], Ratio: 0.7235118875326746
# 이미지 280: Dominant Color: [24, 25, 24], Ratio: 0.6621746538099036
# 이미지 284: Dominant Color: [57, 70, 60], Ratio: 0.7367350825532164
# 이미지 285: Dominant Color: [67, 59, 37], Ratio: 0.6843270325415638
# 이미지 286: Dominant Color: [23, 37, 50], Ratio: 0.5094402948642843
# 이미지 287: Dominant Color: [43, 38, 36], Ratio: 0.510147093754164
# 이미지 289: Dominant Color: [28, 27, 32], Ratio: 0.5781457293873394
# 이미지 291: Dominant Color: [156, 146, 128], Ratio: 0.5357136776728649
# 이미지 293: Dominant Color: [73, 76, 87], Ratio: 0.48082718610498537
# 이미지 294: Dominant Color: [149, 122, 108], Ratio: 0.41242093102308897
# 이미지 296: Dominant Color: [31, 33, 39], Ratio: 0.7650151477643786
# 이미지 297: Dominant Color: [46, 47, 46], Ratio: 0.9090792917556074
# 이미지 299: Dominant Color: [20, 21, 25], Ratio: 0.8795978222848071
# 이미지 300: Dominant Color: [37, 25, 35], Ratio: 0.5927713900115931
# 이미지 301: Dominant Color: [229, 230, 234], Ratio: 0.7342885197973141
# 이미지 302: Dominant Color: [34, 34, 34], Ratio: 0.5198174719939112
# 이미지 303: Dominant Color: [217, 212, 211], Ratio: 0.5065044863228516
# 이미지 304: Dominant Color: [233, 215, 189], Ratio: 0.4653135825714727
# 이미지 305: Dominant Color: [225, 198, 181], Ratio: 0.3986338438616096
# 이미지 306: Dominant Color: [17, 20, 19], Ratio: 0.5948790424204915
# 이미지 307: Dominant Color: [36, 86, 167], Ratio: 0.5622865895299604
# 이미지 308: Dominant Color: [88, 88, 90], Ratio: 0.9311830686699579
# 이미지 309: Dominant Color: [171, 131, 103], Ratio: 0.3462148257895917
# 이미지 310: Dominant Color: [35, 34, 41], Ratio: 0.5532053448927243
# 이미지 311: Dominant Color: [66, 70, 75], Ratio: 0.6349557911638667
# 이미지 313: Dominant Color: [58, 53, 40], Ratio: 0.5770192157475394
# 이미지 314: Dominant Color: [102, 83, 84], Ratio: 0.5419358362588199
# 이미지 316: Dominant Color: [15, 22, 21], Ratio: 0.8463390142918059
# 이미지 317: Dominant Color: [151, 153, 73], Ratio: 0.5153943449345139
# 이미지 318: Dominant Color: [21, 22, 21], Ratio: 0.529460059612096
# 이미지 319: Dominant Color: [49, 36, 32], Ratio: 0.5764869391682406
# 이미지 320: Dominant Color: [236, 236, 232], Ratio: 0.3838523406888018
# 이미지 321: Dominant Color: [25, 25, 25], Ratio: 0.9513926636929557
# 이미지 322: Dominant Color: [27, 32, 39], Ratio: 0.5219100228395389
# 이미지 323: Dominant Color: [138, 113, 89], Ratio: 0.7185072433340332
# 이미지 324: Dominant Color: [216, 204, 196], Ratio: 0.6784630415603345
# 이미지 326: Dominant Color: [21, 23, 24], Ratio: 0.6588091083366103
# 이미지 329: Dominant Color: [24, 23, 25], Ratio: 0.7873873432087176
# 이미지 330: Dominant Color: [67, 67, 67], Ratio: 0.5677363364544278
# 이미지 331: Dominant Color: [55, 43, 38], Ratio: 0.3955456470518059
# 이미지 332: Dominant Color: [141, 152, 154], Ratio: 0.6890874183916459
# 이미지 333: Dominant Color: [22, 28, 25], Ratio: 0.6138733915532527
# 이미지 334: Dominant Color: [47, 34, 26], Ratio: 0.44954118653198893
# 이미지 335: Dominant Color: [24, 25, 28], Ratio: 0.8449360405166452
# 이미지 337: Dominant Color: [101, 101, 106], Ratio: 0.7154014151362524
# 이미지 338: Dominant Color: [189, 184, 169], Ratio: 0.5366763491046488
# 이미지 339: Dominant Color: [69, 74, 79], Ratio: 0.8758620450534477
# 이미지 342: Dominant Color: [144, 140, 112], Ratio: 0.6970227050817259
# 이미지 344: Dominant Color: [145, 53, 65], Ratio: 0.6537484013170426
# 이미지 345: Dominant Color: [95, 125, 149], Ratio: 0.8945531493899087
# 이미지 347: Dominant Color: [210, 203, 173], Ratio: 0.7191976708510962
# 이미지 348: Dominant Color: [138, 147, 160], Ratio: 0.5028048801109269
# 이미지 349: Dominant Color: [37, 38, 42], Ratio: 0.7044203763286556
# 이미지 350: Dominant Color: [45, 41, 41], Ratio: 0.5167345003358754
# 이미지 351: Dominant Color: [34, 35, 37], Ratio: 0.6687972323093532
# 이미지 352: Dominant Color: [185, 184, 203], Ratio: 0.6335271708966144
# 이미지 353: Dominant Color: [22, 21, 34], Ratio: 0.7116648620069024
# 이미지 354: Dominant Color: [17, 16, 18], Ratio: 0.45700198918723917
# 이미지 356: Dominant Color: [23, 22, 23], Ratio: 0.9612762592695488
# 이미지 357: Dominant Color: [181, 197, 197], Ratio: 0.8616901900154605
# 이미지 358: Dominant Color: [150, 151, 156], Ratio: 0.90009038306727
# 이미지 359: Dominant Color: [211, 199, 182], Ratio: 0.8854427969735109
# 이미지 361: Dominant Color: [189, 197, 193], Ratio: 0.4275671968557938
# 이미지 362: Dominant Color: [202, 222, 221], Ratio: 0.6549999745120328
# 이미지 363: Dominant Color: [26, 26, 28], Ratio: 0.741782196348321
# 이미지 364: Dominant Color: [219, 210, 205], Ratio: 0.44649526159367464
# 이미지 366: Dominant Color: [29, 30, 34], Ratio: 0.6069875661369722
# 이미지 367: Dominant Color: [166, 167, 166], Ratio: 0.47129112721225797
# 이미지 368: Dominant Color: [155, 98, 58], Ratio: 0.5146495390265957
# 이미지 369: Dominant Color: [42, 40, 47], Ratio: 0.5981905852818722
# 이미지 370: Dominant Color: [105, 118, 121], Ratio: 0.4019534101411906
# 이미지 371: Dominant Color: [168, 169, 171], Ratio: 0.7955576420238986
# 이미지 372: Dominant Color: [43, 43, 46], Ratio: 0.5544673011974209
# 이미지 373: Dominant Color: [204, 194, 176], Ratio: 0.5331387699311451
# 이미지 374: Dominant Color: [17, 24, 42], Ratio: 0.9146676994577847
# 이미지 375: Dominant Color: [196, 189, 200], Ratio: 0.5361387035205283
# 이미지 376: Dominant Color: [36, 33, 39], Ratio: 0.8114276663209896
# 이미지 377: Dominant Color: [223, 222, 230], Ratio: 0.8757164560458532
# 이미지 378: Dominant Color: [228, 232, 240], Ratio: 0.4574300735847479
# 이미지 379: Dominant Color: [35, 36, 39], Ratio: 0.5444623515204944
# 이미지 380: Dominant Color: [232, 232, 234], Ratio: 0.5807277312095696
# 이미지 381: Dominant Color: [44, 46, 54], Ratio: 0.7339080836556743
# 이미지 382: Dominant Color: [29, 28, 34], Ratio: 0.4598146577208812
# 이미지 383: Dominant Color: [192, 182, 171], Ratio: 0.5270829321803467
# 이미지 385: Dominant Color: [32, 25, 25], Ratio: 0.49587134344353845
# 이미지 386: Dominant Color: [19, 21, 20], Ratio: 0.6618553600962261
# 이미지 387: Dominant Color: [36, 34, 35], Ratio: 0.6691000128301713
# 이미지 388: Dominant Color: [24, 24, 24], Ratio: 0.6783120068559946
# 이미지 390: Dominant Color: [194, 187, 185], Ratio: 0.5906854007083574
# 이미지 391: Dominant Color: [26, 27, 29], Ratio: 0.6027363761588584
# 이미지 392: Dominant Color: [232, 224, 219], Ratio: 0.5241964778885245
# 이미지 393: Dominant Color: [143, 122, 105], Ratio: 0.7688755985119524
# 이미지 394: Dominant Color: [18, 24, 35], Ratio: 0.8901205653997636
# 이미지 396: Dominant Color: [43, 43, 43], Ratio: 0.518197822048313
# 이미지 397: Dominant Color: [216, 207, 197], Ratio: 0.5478981995670877
# 이미지 398: Dominant Color: [39, 22, 16], Ratio: 0.5013897316188453
# 이미지 399: Dominant Color: [164, 164, 164], Ratio: 0.8692909753847505
# 이미지 401: Dominant Color: [133, 111, 126], Ratio: 0.5246300248399398
# 이미지 402: Dominant Color: [146, 98, 72], Ratio: 0.34918689310877216
# 이미지 403: Dominant Color: [153, 142, 131], Ratio: 0.43775650252736586
# 이미지 404: Dominant Color: [15, 20, 14], Ratio: 0.8427936675114374
# 이미지 405: Dominant Color: [87, 36, 41], Ratio: 0.4125103020453541
# 이미지 407: Dominant Color: [234, 230, 231], Ratio: 0.4557617998627713
# 이미지 408: Dominant Color: [155, 130, 109], Ratio: 0.5885385826771653
# 이미지 411: Dominant Color: [42, 42, 46], Ratio: 0.7000911528718454
# 이미지 412: Dominant Color: [42, 43, 49], Ratio: 0.7090290215518339
# 이미지 414: Dominant Color: [35, 35, 38], Ratio: 0.7842884054448226
# 이미지 415: Dominant Color: [16, 36, 42], Ratio: 0.5929388354036489
# 이미지 417: Dominant Color: [214, 204, 196], Ratio: 0.6618294560291094
# 이미지 418: Dominant Color: [253, 253, 253], Ratio: 0.6395284288339312
# 이미지 419: Dominant Color: [44, 34, 16], Ratio: 0.4195659538276357
# 이미지 420: Dominant Color: [22, 22, 30], Ratio: 0.9547278836390659
# 이미지 421: Dominant Color: [224, 223, 226], Ratio: 0.6694901086653664
# 이미지 422: Dominant Color: [222, 188, 185], Ratio: 0.5356201145028345
# 이미지 424: Dominant Color: [51, 70, 58], Ratio: 0.6371472177136074
# 이미지 425: Dominant Color: [50, 46, 42], Ratio: 0.751774928957155
# 이미지 426: Dominant Color: [65, 66, 61], Ratio: 0.6018262205777114
# 이미지 427: Dominant Color: [227, 184, 185], Ratio: 0.6128721891180873
# 이미지 428: Dominant Color: [34, 34, 34], Ratio: 0.9561229264908486
# 이미지 429: Dominant Color: [216, 212, 222], Ratio: 0.555062078985603
# 이미지 430: Dominant Color: [35, 35, 38], Ratio: 0.8212850945966053
# 이미지 431: Dominant Color: [132, 100, 78], Ratio: 0.4016525839129826
# 이미지 433: Dominant Color: [82, 68, 66], Ratio: 0.9777713589078104
# 이미지 434: Dominant Color: [12, 12, 15], Ratio: 0.8748776266996292
# 이미지 435: Dominant Color: [216, 216, 219], Ratio: 0.5815756882918929
# 이미지 436: Dominant Color: [24, 25, 31], Ratio: 0.5254844726933573
# 이미지 437: Dominant Color: [52, 53, 56], Ratio: 0.4004089184997404
# 이미지 438: Dominant Color: [33, 33, 33], Ratio: 0.5805886495860041
# 이미지 439: Dominant Color: [122, 171, 206], Ratio: 0.457619454353615
# 이미지 440: Dominant Color: [115, 114, 122], Ratio: 0.47365747683485127
# 이미지 441: Dominant Color: [215, 170, 143], Ratio: 0.5195129424314295
# 이미지 442: Dominant Color: [36, 35, 33], Ratio: 0.7417387476989594
# 이미지 443: Dominant Color: [106, 81, 54], Ratio: 0.6923706043294806
# 이미지 444: Dominant Color: [30, 43, 48], Ratio: 0.8571068027042011
# 이미지 445: Dominant Color: [18, 19, 23], Ratio: 0.8958345548313864
# 이미지 446: Dominant Color: [25, 23, 22], Ratio: 0.8371610765493048
# 이미지 447: Dominant Color: [186, 184, 192], Ratio: 0.6788947590919486
# 이미지 448: Dominant Color: [84, 71, 63], Ratio: 0.4759162266757837
# 이미지 449: Dominant Color: [132, 116, 89], Ratio: 0.6346733101275163
# 이미지 450: Dominant Color: [30, 30, 27], Ratio: 0.9038126324999158
# 이미지 453: Dominant Color: [29, 32, 47], Ratio: 0.9418030025984024
# 이미지 454: Dominant Color: [188, 203, 221], Ratio: 0.42007814756815104
# 이미지 455: Dominant Color: [24, 24, 25], Ratio: 0.9661413738538573
# 이미지 457: Dominant Color: [215, 209, 201], Ratio: 0.7401079835864949
# 이미지 458: Dominant Color: [41, 49, 48], Ratio: 0.5724556626683347
# 이미지 460: Dominant Color: [26, 26, 26], Ratio: 0.716667127160869
# 이미지 461: Dominant Color: [28, 23, 14], Ratio: 0.8996315366809958
# 이미지 462: Dominant Color: [133, 144, 162], Ratio: 0.4403175781932553
# 이미지 463: Dominant Color: [209, 201, 192], Ratio: 0.5270238164612854
# 이미지 464: Dominant Color: [72, 76, 78], Ratio: 0.5248370218780987
# 이미지 465: Dominant Color: [70, 64, 68], Ratio: 0.6260687266429679
# 이미지 468: Dominant Color: [130, 115, 112], Ratio: 0.3979675249166248
# 이미지 469: Dominant Color: [39, 34, 33], Ratio: 0.47780362068076265
# 이미지 470: Dominant Color: [26, 24, 29], Ratio: 0.979987963830549
# 이미지 471: Dominant Color: [29, 28, 28], Ratio: 0.7985204984818111
# 이미지 472: Dominant Color: [52, 52, 52], Ratio: 0.7791134298517409
# 이미지 473: Dominant Color: [204, 190, 184], Ratio: 0.4270182865105762
# 이미지 474: Dominant Color: [26, 25, 23], Ratio: 0.7480515667538569
# 이미지 476: Dominant Color: [51, 22, 8], Ratio: 0.4856889585298883
# 이미지 477: Dominant Color: [77, 11, 21], Ratio: 0.5800235460982998
# 이미지 479: Dominant Color: [223, 191, 174], Ratio: 0.37492941120749645
# 이미지 482: Dominant Color: [11, 23, 24], Ratio: 0.6930810810810811
# 이미지 483: Dominant Color: [28, 27, 29], Ratio: 0.9825596585960634
# 이미지 484: Dominant Color: [196, 193, 192], Ratio: 0.5561562057249756
# 이미지 485: Dominant Color: [121, 130, 125], Ratio: 0.48054118745837365
# 이미지 487: Dominant Color: [125, 136, 123], Ratio: 0.7866264841353809
# 이미지 489: Dominant Color: [216, 198, 188], Ratio: 0.443598668859733
# 이미지 491: Dominant Color: [25, 25, 27], Ratio: 0.5441309921640931
# 이미지 492: Dominant Color: [37, 33, 30], Ratio: 0.5392243402327754
# 이미지 494: Dominant Color: [205, 167, 161], Ratio: 0.47373912458139106
# 이미지 495: Dominant Color: [98, 99, 98], Ratio: 0.6183745834807826
# 이미지 499: Dominant Color: [76, 78, 81], Ratio: 0.5498362627815278
# 이미지 500: Dominant Color: [231, 238, 246], Ratio: 0.475993984962406
# 이미지 501: Dominant Color: [190, 189, 189], Ratio: 0.5811111959093337
# 이미지 503: Dominant Color: [156, 140, 139], Ratio: 0.8226609417571288
# 이미지 504: Dominant Color: [172, 69, 45], Ratio: 0.9077322569032952
# 이미지 505: Dominant Color: [207, 200, 192], Ratio: 0.38199450615072256
# 이미지 506: Dominant Color: [27, 29, 37], Ratio: 0.594421737914875
# 이미지 508: Dominant Color: [26, 26, 26], Ratio: 0.9834740561342976
# 이미지 509: Dominant Color: [91, 92, 86], Ratio: 0.8307976931489338
# 이미지 510: Dominant Color: [234, 233, 237], Ratio: 0.8824792555870735
# 이미지 511: Dominant Color: [61, 61, 63], Ratio: 0.6998144946846697
# 이미지 512: Dominant Color: [65, 70, 76], Ratio: 0.629431718284707
# 이미지 513: Dominant Color: [45, 44, 44], Ratio: 0.5614220507236868
# 이미지 514: Dominant Color: [65, 64, 63], Ratio: 0.7020443943520867
# 이미지 515: Dominant Color: [35, 29, 27], Ratio: 0.6308263714450885
# 이미지 517: Dominant Color: [180, 189, 186], Ratio: 0.5426184428724364
# 이미지 518: Dominant Color: [59, 44, 47], Ratio: 0.5520180176197388
# 이미지 519: Dominant Color: [65, 58, 56], Ratio: 0.36184935346077274
# 이미지 520: Dominant Color: [219, 214, 209], Ratio: 0.8903989511332583
# 이미지 522: Dominant Color: [19, 19, 27], Ratio: 0.9388415494082691
# 이미지 523: Dominant Color: [35, 42, 46], Ratio: 0.4994471991423211
# 이미지 524: Dominant Color: [232, 230, 230], Ratio: 0.8118180850497632
# 이미지 525: Dominant Color: [86, 75, 75], Ratio: 0.429297137314398
# 이미지 526: Dominant Color: [30, 35, 48], Ratio: 0.9258674976184638
# 이미지 527: Dominant Color: [177, 183, 195], Ratio: 0.7311939922727597
# 이미지 528: Dominant Color: [227, 231, 238], Ratio: 0.7368040006971724
# 이미지 529: Dominant Color: [135, 90, 92], Ratio: 0.4316576231812494
# 이미지 530: Dominant Color: [30, 32, 44], Ratio: 0.9438904290975297
# 이미지 531: Dominant Color: [23, 24, 22], Ratio: 0.6149040543176747
# 이미지 532: Dominant Color: [41, 35, 40], Ratio: 0.45411873595134206
# 이미지 533: Dominant Color: [54, 36, 29], Ratio: 0.5804001064766469
# 이미지 534: Dominant Color: [71, 74, 79], Ratio: 0.6491822684651568
# 이미지 535: Dominant Color: [38, 39, 45], Ratio: 0.7357698958141331
# 이미지 537: Dominant Color: [200, 201, 202], Ratio: 0.5166052324013306
# 이미지 538: Dominant Color: [74, 66, 58], Ratio: 0.6665699892464962
# 이미지 539: Dominant Color: [138, 95, 51], Ratio: 0.5515075049228643
# 이미지 540: Dominant Color: [239, 239, 241], Ratio: 0.4727517380578605
# 이미지 541: Dominant Color: [69, 29, 31], Ratio: 0.9428259223779085
# 이미지 542: Dominant Color: [58, 37, 47], Ratio: 0.832023305922813
# 이미지 543: Dominant Color: [24, 22, 27], Ratio: 0.4195442238379551
# 이미지 545: Dominant Color: [10, 18, 33], Ratio: 0.6489593005484651
# 이미지 546: Dominant Color: [179, 153, 137], Ratio: 0.39535564098497816
# 이미지 547: Dominant Color: [145, 138, 120], Ratio: 0.6138473357898188
# 이미지 548: Dominant Color: [109, 136, 163], Ratio: 0.6433778180306651
# 이미지 550: Dominant Color: [24, 23, 26], Ratio: 0.5048726998595072
# 이미지 551: Dominant Color: [23, 25, 29], Ratio: 0.9512409855380194
# 이미지 552: Dominant Color: [5, 13, 22], Ratio: 0.883636067373332
# 이미지 553: Dominant Color: [213, 190, 171], Ratio: 0.5709647860753038
# 이미지 554: Dominant Color: [184, 187, 195], Ratio: 0.6746350757412831
# 이미지 555: Dominant Color: [96, 82, 85], Ratio: 0.44379758322268115
# 이미지 557: Dominant Color: [29, 28, 29], Ratio: 0.6196117188809133
# 이미지 558: Dominant Color: [31, 31, 30], Ratio: 0.654489288494864
# 이미지 559: Dominant Color: [40, 39, 40], Ratio: 0.6230017004944111
# 이미지 562: Dominant Color: [34, 38, 48], Ratio: 0.9466485709076914
# 이미지 563: Dominant Color: [47, 48, 51], Ratio: 0.5891947758005474
# 이미지 564: Dominant Color: [53, 44, 38], Ratio: 0.4774533506912157
# 이미지 565: Dominant Color: [226, 215, 209], Ratio: 0.3975295205963977
# 이미지 566: Dominant Color: [55, 55, 56], Ratio: 0.6087790078589588
# 이미지 568: Dominant Color: [18, 18, 25], Ratio: 0.5336047750066566
# 이미지 569: Dominant Color: [211, 208, 207], Ratio: 0.4475606429516776
# 이미지 572: Dominant Color: [204, 197, 187], Ratio: 0.45662990907332174
# 이미지 573: Dominant Color: [108, 108, 111], Ratio: 0.5199244016582862
# 이미지 574: Dominant Color: [92, 87, 75], Ratio: 0.4690424737100026
# 이미지 575: Dominant Color: [211, 222, 106], Ratio: 0.8739747455946998
# 이미지 577: Dominant Color: [23, 27, 32], Ratio: 0.7925595001110585
# 이미지 578: Dominant Color: [14, 16, 17], Ratio: 0.9495524034953461
# 이미지 579: Dominant Color: [28, 30, 29], Ratio: 0.975738491258919
# 이미지 580: Dominant Color: [25, 26, 31], Ratio: 0.8430928781140785
# 이미지 581: Dominant Color: [175, 167, 136], Ratio: 0.6074728373814281
# 이미지 582: Dominant Color: [25, 29, 39], Ratio: 0.9741086286616601
# 이미지 583: Dominant Color: [229, 229, 229], Ratio: 0.8823939275232952
# 이미지 584: Dominant Color: [32, 35, 49], Ratio: 0.8599609349047954
# 이미지 585: Dominant Color: [19, 41, 32], Ratio: 0.8293087792662361
# 이미지 586: Dominant Color: [48, 47, 60], Ratio: 0.8540925266903915
# 이미지 587: Dominant Color: [228, 226, 219], Ratio: 0.4576018937352052
# 이미지 588: Dominant Color: [131, 147, 168], Ratio: 0.6060676851468216
# 이미지 589: Dominant Color: [31, 35, 39], Ratio: 0.9403515713316754
# 이미지 590: Dominant Color: [111, 101, 103], Ratio: 0.5494864555450986
# 이미지 591: Dominant Color: [234, 235, 233], Ratio: 0.9456053511705685
# 이미지 593: Dominant Color: [16, 20, 31], Ratio: 0.6166835528537656
# 이미지 594: Dominant Color: [139, 140, 147], Ratio: 0.5352534617991672
# 이미지 595: Dominant Color: [62, 46, 37], Ratio: 0.6775414946224275
# 이미지 596: Dominant Color: [184, 185, 193], Ratio: 0.5289007315049898
# 이미지 597: Dominant Color: [19, 18, 20], Ratio: 0.8820068393685295
# 이미지 598: Dominant Color: [168, 151, 131], Ratio: 0.44171749842620533
# 이미지 599: Dominant Color: [220, 206, 200], Ratio: 0.563113880541127
# 이미지 600: Dominant Color: [180, 190, 200], Ratio: 0.4121766551664923
# 이미지 602: Dominant Color: [218, 214, 204], Ratio: 0.8293507585578641
# 이미지 605: Dominant Color: [28, 32, 35], Ratio: 0.5723490965013457
# 이미지 606: Dominant Color: [26, 25, 26], Ratio: 0.6038770740319978
# 이미지 608: Dominant Color: [64, 66, 72], Ratio: 0.5674393501085758
# 이미지 610: Dominant Color: [209, 208, 201], Ratio: 0.6543125707157156
# 이미지 611: Dominant Color: [225, 220, 211], Ratio: 0.4548929041911298
# 이미지 613: Dominant Color: [60, 58, 54], Ratio: 0.7456409575791761
# 이미지 614: Dominant Color: [36, 41, 50], Ratio: 0.7446459956169853
# 이미지 615: Dominant Color: [61, 45, 30], Ratio: 0.5075754583161259
# 이미지 617: Dominant Color: [90, 41, 30], Ratio: 0.5482702398747644
# 이미지 618: Dominant Color: [211, 204, 196], Ratio: 0.5246805025057764
# 이미지 619: Dominant Color: [35, 35, 34], Ratio: 0.7208212676962676
# 이미지 621: Dominant Color: [190, 194, 194], Ratio: 0.47618636469298975
# 이미지 622: Dominant Color: [21, 33, 45], Ratio: 0.6508499600957701
# 이미지 624: Dominant Color: [25, 26, 27], Ratio: 0.5414915854132915
# 이미지 626: Dominant Color: [79, 62, 52], Ratio: 0.4376793546883533
# 이미지 629: Dominant Color: [96, 84, 68], Ratio: 0.49793905874986955
# 이미지 630: Dominant Color: [77, 75, 75], Ratio: 0.6630405231506487
# 이미지 632: Dominant Color: [242, 214, 214], Ratio: 0.40444444444444444
# 이미지 633: Dominant Color: [19, 19, 27], Ratio: 0.8244434263350391
# 이미지 635: Dominant Color: [61, 62, 56], Ratio: 0.5403106555089494
# 이미지 636: Dominant Color: [186, 184, 173], Ratio: 0.6580313476483002
# 이미지 637: Dominant Color: [165, 125, 110], Ratio: 0.4114452753522953
# 이미지 638: Dominant Color: [118, 73, 70], Ratio: 0.43765172971879424
# 이미지 639: Dominant Color: [202, 177, 163], Ratio: 0.49164141369390446
# 이미지 641: Dominant Color: [172, 156, 129], Ratio: 0.7391811598128984
# 이미지 642: Dominant Color: [34, 34, 36], Ratio: 0.8187807374399108
# 이미지 643: Dominant Color: [230, 229, 228], Ratio: 0.5669737436547867
# 이미지 644: Dominant Color: [141, 117, 82], Ratio: 0.4177941104244851
# 이미지 645: Dominant Color: [23, 20, 25], Ratio: 0.7932833895827511
# 이미지 646: Dominant Color: [22, 23, 26], Ratio: 0.8150054227312605
# 이미지 647: Dominant Color: [60, 58, 63], Ratio: 0.6938327103747853
# 이미지 648: Dominant Color: [212, 201, 212], Ratio: 0.6388437015014679
# 이미지 649: Dominant Color: [30, 30, 30], Ratio: 0.9896041075922286
# 이미지 650: Dominant Color: [245, 237, 201], Ratio: 0.46285993814826176
# 이미지 651: Dominant Color: [14, 12, 17], Ratio: 0.6022450405565514
# 이미지 652: Dominant Color: [217, 229, 241], Ratio: 0.7897048751277038
# 이미지 653: Dominant Color: [199, 199, 195], Ratio: 0.6186016278990207
# 이미지 654: Dominant Color: [29, 27, 31], Ratio: 0.9609688282340431
# 이미지 655: Dominant Color: [15, 15, 15], Ratio: 0.8884345376215483
# 이미지 656: Dominant Color: [97, 95, 108], Ratio: 0.46504099720365893
# 이미지 658: Dominant Color: [54, 54, 55], Ratio: 0.48507253269214295
# 이미지 659: Dominant Color: [16, 16, 12], Ratio: 0.9597759687263895
# 이미지 660: Dominant Color: [49, 50, 47], Ratio: 0.7417193213285804
# 이미지 661: Dominant Color: [46, 37, 36], Ratio: 0.5847604520557443
# 이미지 662: Dominant Color: [171, 158, 153], Ratio: 0.48317222600408444
# 이미지 664: Dominant Color: [32, 34, 37], Ratio: 0.6095742765748259
# 이미지 665: Dominant Color: [149, 162, 185], Ratio: 0.4812358084544923
# 이미지 666: Dominant Color: [224, 167, 57], Ratio: 0.6378851790394368
# 이미지 667: Dominant Color: [18, 19, 23], Ratio: 0.7236540284143198
# 이미지 668: Dominant Color: [91, 93, 74], Ratio: 0.6706306333723897
# 이미지 669: Dominant Color: [63, 67, 72], Ratio: 0.4701006170775451
# 이미지 671: Dominant Color: [22, 21, 16], Ratio: 0.7931691231860369
# 이미지 673: Dominant Color: [24, 28, 35], Ratio: 0.5934679122179461
# 이미지 674: Dominant Color: [195, 193, 179], Ratio: 0.42721018287279466
# 이미지 676: Dominant Color: [208, 173, 143], Ratio: 0.3705783580789677
# 이미지 677: Dominant Color: [193, 204, 210], Ratio: 0.6845474528556554
# 이미지 678: Dominant Color: [222, 216, 197], Ratio: 0.8798240530796545
# 이미지 679: Dominant Color: [35, 37, 36], Ratio: 0.4537070136555373
# 이미지 680: Dominant Color: [34, 27, 18], Ratio: 0.4979668775210556
# 이미지 682: Dominant Color: [73, 78, 81], Ratio: 0.5679912299125552
# 이미지 683: Dominant Color: [199, 183, 108], Ratio: 0.8422796447681928
# 이미지 684: Dominant Color: [31, 31, 31], Ratio: 0.6108135467738401
# 이미지 686: Dominant Color: [123, 134, 99], Ratio: 0.5899991619560486
# 이미지 687: Dominant Color: [22, 21, 26], Ratio: 0.6454642998324642
# 이미지 689: Dominant Color: [79, 50, 36], Ratio: 0.5672806097089523
# 이미지 690: Dominant Color: [26, 25, 19], Ratio: 0.42402370891353053
# 이미지 691: Dominant Color: [183, 169, 154], Ratio: 0.5024264753041111
# 이미지 693: Dominant Color: [31, 31, 40], Ratio: 0.7706802804708689
# 이미지 694: Dominant Color: [113, 37, 44], Ratio: 0.5910196940649676
# 이미지 695: Dominant Color: [105, 117, 132], Ratio: 0.5225938093820829
# 이미지 697: Dominant Color: [15, 27, 43], Ratio: 0.5505764014466547
# 이미지 698: Dominant Color: [227, 71, 54], Ratio: 0.5151188459366497
# 이미지 699: Dominant Color: [40, 41, 40], Ratio: 0.9044400070652125
# 이미지 700: Dominant Color: [193, 176, 155], Ratio: 0.3995913441072922
# 이미지 701: Dominant Color: [21, 20, 21], Ratio: 0.6603054775280899
# 이미지 702: Dominant Color: [55, 55, 60], Ratio: 0.48511187082201396
# 이미지 703: Dominant Color: [201, 199, 177], Ratio: 0.5655240575679911
# 이미지 704: Dominant Color: [47, 52, 53], Ratio: 0.6603938904543692
# 이미지 705: Dominant Color: [82, 121, 168], Ratio: 0.4093743672808261
# 이미지 706: Dominant Color: [236, 231, 228], Ratio: 0.5893296869820523
# 이미지 707: Dominant Color: [35, 30, 28], Ratio: 0.8309930872731761
# 이미지 708: Dominant Color: [174, 173, 163], Ratio: 0.506096104503181
# 이미지 709: Dominant Color: [41, 41, 47], Ratio: 0.6541888351109504
# 이미지 711: Dominant Color: [165, 136, 113], Ratio: 0.6117559891331192
# 이미지 712: Dominant Color: [32, 18, 18], Ratio: 0.6767314182621273
# 이미지 714: Dominant Color: [44, 48, 52], Ratio: 0.5706868955870288
# 이미지 715: Dominant Color: [38, 41, 44], Ratio: 0.6906326746153943
# 이미지 717: Dominant Color: [170, 165, 145], Ratio: 0.5149985304676833
# 이미지 718: Dominant Color: [25, 25, 29], Ratio: 0.7528318263698973
# 이미지 719: Dominant Color: [207, 191, 177], Ratio: 0.5908220775867442
# 이미지 720: Dominant Color: [20, 47, 59], Ratio: 0.4674614975816885
# 이미지 721: Dominant Color: [225, 215, 206], Ratio: 0.55040299388799
# 이미지 722: Dominant Color: [26, 24, 29], Ratio: 0.6115968854854905
# 이미지 723: Dominant Color: [35, 51, 70], Ratio: 0.35917613222659095
# 이미지 724: Dominant Color: [29, 28, 32], Ratio: 0.8010756520138035
# 이미지 725: Dominant Color: [196, 195, 211], Ratio: 0.4356394202497492
# 이미지 726: Dominant Color: [51, 47, 38], Ratio: 0.522808510168115
# 이미지 727: Dominant Color: [118, 89, 86], Ratio: 0.5941455611071855
# 이미지 728: Dominant Color: [22, 22, 24], Ratio: 0.6743793211816468
# 이미지 729: Dominant Color: [212, 211, 213], Ratio: 0.42628251000943146
# 이미지 730: Dominant Color: [193, 173, 163], Ratio: 0.41640722848452316
# 이미지 731: Dominant Color: [158, 103, 86], Ratio: 0.42055152495124776
# 이미지 732: Dominant Color: [142, 143, 143], Ratio: 0.43729228247474244
# 이미지 733: Dominant Color: [107, 119, 131], Ratio: 0.5498020794462615
# 이미지 734: Dominant Color: [25, 25, 28], Ratio: 0.6668612323621967
# 이미지 735: Dominant Color: [58, 61, 69], Ratio: 0.5554340072864988
# 이미지 737: Dominant Color: [143, 107, 96], Ratio: 0.4681030259799414
# 이미지 738: Dominant Color: [48, 47, 52], Ratio: 0.5957570321713505
# 이미지 740: Dominant Color: [153, 133, 90], Ratio: 0.811672696667286
# 이미지 741: Dominant Color: [30, 34, 45], Ratio: 0.8373675826117141
# 이미지 742: Dominant Color: [220, 212, 192], Ratio: 0.9223916952546134
# 이미지 743: Dominant Color: [187, 165, 149], Ratio: 0.6621405862337022
# 이미지 744: Dominant Color: [223, 198, 172], Ratio: 0.7010633755080223
# 이미지 745: Dominant Color: [40, 42, 48], Ratio: 0.7313999987561648
# 이미지 749: Dominant Color: [152, 109, 86], Ratio: 0.5002528293348842
# 이미지 751: Dominant Color: [24, 25, 28], Ratio: 0.5560736283473197
# 이미지 752: Dominant Color: [128, 126, 121], Ratio: 0.4791655153357281
# 이미지 753: Dominant Color: [13, 18, 21], Ratio: 0.6589052437462213
# 이미지 754: Dominant Color: [36, 36, 51], Ratio: 0.6830736380043235
# 이미지 755: Dominant Color: [35, 36, 42], Ratio: 0.785581396326607
# 이미지 756: Dominant Color: [225, 228, 238], Ratio: 0.5460787454213729
# 이미지 758: Dominant Color: [57, 56, 58], Ratio: 0.40593360018836827
# 이미지 759: Dominant Color: [22, 23, 21], Ratio: 0.7953075972235428
# 이미지 760: Dominant Color: [145, 19, 42], Ratio: 0.545007481192387
# 이미지 761: Dominant Color: [244, 243, 248], Ratio: 0.6099500290587748
# 이미지 763: Dominant Color: [26, 49, 75], Ratio: 0.5324235369229838
# 이미지 764: Dominant Color: [42, 43, 41], Ratio: 0.5217130673164788
# 이미지 765: Dominant Color: [30, 33, 33], Ratio: 0.6321244395697435
# 이미지 767: Dominant Color: [192, 184, 178], Ratio: 0.4073399024912057
# 이미지 769: Dominant Color: [32, 33, 19], Ratio: 0.7272782012837651
# 이미지 770: Dominant Color: [46, 53, 64], Ratio: 0.6758420178220813
# 이미지 771: Dominant Color: [97, 86, 82], Ratio: 0.554589358873484
# 이미지 772: Dominant Color: [232, 231, 233], Ratio: 0.46197738521588666
# 이미지 773: Dominant Color: [201, 148, 102], Ratio: 0.46250846947225777
# 이미지 774: Dominant Color: [209, 211, 225], Ratio: 0.4859886829673467
# 이미지 775: Dominant Color: [46, 46, 54], Ratio: 0.6918349596541238
# 이미지 776: Dominant Color: [29, 28, 32], Ratio: 0.6815054682108899
# 이미지 777: Dominant Color: [148, 154, 152], Ratio: 0.5301098651203116
# 이미지 778: Dominant Color: [69, 66, 68], Ratio: 0.5164262048473621
# 이미지 780: Dominant Color: [83, 85, 81], Ratio: 0.5971524844179233
# 이미지 781: Dominant Color: [142, 180, 161], Ratio: 0.94845788701941
# 이미지 783: Dominant Color: [223, 215, 201], Ratio: 0.6453691309830725
# 이미지 784: Dominant Color: [51, 51, 51], Ratio: 0.519721924796876
# 이미지 785: Dominant Color: [119, 110, 90], Ratio: 0.5368080577515965
# 이미지 786: Dominant Color: [118, 93, 68], Ratio: 0.6742960218289697
# 이미지 787: Dominant Color: [213, 214, 219], Ratio: 0.5764176473000123
# 이미지 788: Dominant Color: [168, 184, 201], Ratio: 0.9030609492179772
# 이미지 790: Dominant Color: [14, 15, 18], Ratio: 0.7097032910436906
# 이미지 791: Dominant Color: [186, 203, 217], Ratio: 0.6198370788816571
# 이미지 792: Dominant Color: [179, 184, 196], Ratio: 0.6929467834312171
# 이미지 794: Dominant Color: [210, 202, 208], Ratio: 0.7420610001584572
# 이미지 796: Dominant Color: [24, 19, 17], Ratio: 0.9030129068791127
# 이미지 797: Dominant Color: [232, 230, 225], Ratio: 0.7160106254527892
# 이미지 798: Dominant Color: [225, 225, 227], Ratio: 0.7315261337619953
# 이미지 799: Dominant Color: [224, 178, 153], Ratio: 0.5860808831355774
# 이미지 800: Dominant Color: [208, 199, 184], Ratio: 0.5302460621162232
# 이미지 801: Dominant Color: [9, 11, 17], Ratio: 0.7426039608224041
# 이미지 802: Dominant Color: [33, 25, 12], Ratio: 0.7906293353512422
# 이미지 803: Dominant Color: [101, 80, 50], Ratio: 0.8384379495069006
# 이미지 804: Dominant Color: [25, 26, 31], Ratio: 0.5330045655185034
# 이미지 806: Dominant Color: [26, 26, 26], Ratio: 0.5863928205456641
# 이미지 807: Dominant Color: [28, 30, 29], Ratio: 0.7106820914325819
# 이미지 808: Dominant Color: [12, 18, 24], Ratio: 0.657131351742832
# 이미지 809: Dominant Color: [58, 53, 47], Ratio: 0.5760431699407362
# 이미지 810: Dominant Color: [230, 229, 235], Ratio: 0.6203018409921902
# 이미지 811: Dominant Color: [26, 25, 25], Ratio: 0.6875689327216636
# 이미지 812: Dominant Color: [159, 144, 141], Ratio: 0.8488595937350808
# 이미지 813: Dominant Color: [232, 221, 213], Ratio: 0.5714891361950185
# 이미지 814: Dominant Color: [27, 26, 31], Ratio: 0.9798328610151132
# 이미지 815: Dominant Color: [37, 35, 37], Ratio: 0.6568711761028925
# 이미지 816: Dominant Color: [63, 87, 105], Ratio: 0.454946835443038
# 이미지 817: Dominant Color: [215, 212, 208], Ratio: 0.6403295720547918
# 이미지 818: Dominant Color: [237, 221, 203], Ratio: 0.5293974448402908
# 이미지 820: Dominant Color: [79, 77, 51], Ratio: 0.6546361072591577
# 이미지 821: Dominant Color: [17, 19, 22], Ratio: 0.830527290963242
# 이미지 822: Dominant Color: [67, 66, 71], Ratio: 0.6254067374868408
# 이미지 823: Dominant Color: [131, 137, 126], Ratio: 0.6735272586860163
# 이미지 824: Dominant Color: [31, 35, 40], Ratio: 0.6593372481879131
# 이미지 825: Dominant Color: [157, 148, 129], Ratio: 0.4041096232263088
# 이미지 827: Dominant Color: [18, 29, 43], Ratio: 0.5195280922338061
# 이미지 830: Dominant Color: [39, 36, 31], Ratio: 0.8559775232097291
# 이미지 831: Dominant Color: [168, 152, 134], Ratio: 0.6387371017149867
# ...
# 이미지 2701: Dominant Color: [235, 232, 214], Ratio: 0.6308930356547817
# 이미지 2702: Dominant Color: [35, 35, 34], Ratio: 0.581221048358623
# 이미지 2703: Dominant Color: [64, 42, 27], Ratio: 0.3852812095827178
# 이미지 2704: Dominant Color: [15, 16, 18], Ratio: 0.6507707088850829
# 이미지 2706: Dominant Color: [108, 89, 61], Ratio: 0.869305056514322
# 이미지 2707: Dominant Color: [211, 199, 191], Ratio: 0.5596126727460751
# 이미지 2709: Dominant Color: [201, 196, 192], Ratio: 0.607005925847708
# 이미지 2710: Dominant Color: [28, 26, 27], Ratio: 0.8514623919636366
# 이미지 2712: Dominant Color: [23, 75, 91], Ratio: 0.6847768098506576
# 이미지 2715: Dominant Color: [31, 27, 25], Ratio: 0.676968000240826
# 이미지 2716: Dominant Color: [192, 177, 151], Ratio: 0.4991190118977007
# 이미지 2717: Dominant Color: [23, 24, 27], Ratio: 0.9304620278886029
# 이미지 2720: Dominant Color: [213, 203, 194], Ratio: 0.7564780750019915
# 이미지 2721: Dominant Color: [43, 38, 34], Ratio: 0.8689132191278177
# 이미지 2722: Dominant Color: [213, 183, 169], Ratio: 0.42257053739544886
# 이미지 2724: Dominant Color: [39, 50, 59], Ratio: 0.7144623987637645
# 이미지 2726: Dominant Color: [160, 161, 182], Ratio: 0.5018303398224433
# 이미지 2727: Dominant Color: [22, 25, 29], Ratio: 0.9406248089502965
# 이미지 2728: Dominant Color: [112, 3, 2], Ratio: 0.6517686019374438
# 이미지 2729: Dominant Color: [193, 195, 197], Ratio: 0.5223609611365322
# 이미지 2730: Dominant Color: [230, 227, 215], Ratio: 0.4935061067537234
# 이미지 2732: Dominant Color: [223, 215, 210], Ratio: 0.5595744252931357
# 이미지 2733: Dominant Color: [33, 33, 34], Ratio: 0.7365135921459057
# 이미지 2734: Dominant Color: [54, 47, 41], Ratio: 0.5848273449535483
# 이미지 2737: Dominant Color: [237, 232, 220], Ratio: 0.4899571654990779
# 이미지 2739: Dominant Color: [188, 176, 163], Ratio: 0.49076720158276543
# 이미지 2741: Dominant Color: [152, 108, 73], Ratio: 0.775553581532526
# 이미지 2743: Dominant Color: [33, 32, 33], Ratio: 0.47901839418805486
# 이미지 2744: Dominant Color: [153, 143, 99], Ratio: 0.8696474213087777
# 이미지 2745: Dominant Color: [29, 27, 32], Ratio: 0.5357551436442626
# 이미지 2746: Dominant Color: [124, 92, 68], Ratio: 0.7762341081032931
# 이미지 2747: Dominant Color: [28, 27, 26], Ratio: 0.7739771220670305
# 이미지 2748: Dominant Color: [32, 31, 30], Ratio: 0.4628519762335314
# 이미지 2749: Dominant Color: [185, 161, 143], Ratio: 0.5331478309668142
# 이미지 2751: Dominant Color: [128, 122, 121], Ratio: 0.3834291350834033
# 이미지 2752: Dominant Color: [41, 43, 53], Ratio: 0.5704505882973672
# 이미지 2753: Dominant Color: [209, 172, 136], Ratio: 0.4943329811984899
# 이미지 2754: Dominant Color: [187, 173, 157], Ratio: 0.5889687404965027
# 이미지 2755: Dominant Color: [202, 82, 78], Ratio: 0.5903599637446588
# 이미지 2756: Dominant Color: [222, 223, 227], Ratio: 0.8748951222720828
# 이미지 2757: Dominant Color: [145, 133, 99], Ratio: 0.45497425894841476
# 이미지 2758: Dominant Color: [33, 33, 33], Ratio: 0.9796541693600517
# 이미지 2759: Dominant Color: [11, 20, 20], Ratio: 0.5389430225700069
# 이미지 2760: Dominant Color: [195, 188, 180], Ratio: 0.5476132265753927
# 이미지 2761: Dominant Color: [77, 77, 65], Ratio: 0.6741161678709005
# 이미지 2762: Dominant Color: [48, 39, 36], Ratio: 0.8463521982081174
# 이미지 2763: Dominant Color: [190, 156, 168], Ratio: 0.4802840454666634
# 이미지 2764: Dominant Color: [123, 93, 75], Ratio: 0.6484763089456675
# 이미지 2765: Dominant Color: [28, 19, 18], Ratio: 0.44860788751999336
# 이미지 2766: Dominant Color: [36, 35, 39], Ratio: 0.709819102210973
# 이미지 2767: Dominant Color: [55, 32, 14], Ratio: 0.4775858072568423
# 이미지 2768: Dominant Color: [43, 44, 37], Ratio: 0.6076191361647482
# 이미지 2769: Dominant Color: [183, 190, 208], Ratio: 0.7650996658601221
# 이미지 2771: Dominant Color: [192, 119, 132], Ratio: 0.43845983323566273
# 이미지 2772: Dominant Color: [26, 42, 51], Ratio: 0.6644234450716069
# 이미지 2773: Dominant Color: [115, 115, 115], Ratio: 0.5547236527106226
# 이미지 2774: Dominant Color: [208, 186, 173], Ratio: 0.5117710615001434
# 이미지 2775: Dominant Color: [155, 163, 166], Ratio: 0.4378741740879058
# 이미지 2777: Dominant Color: [233, 231, 231], Ratio: 0.8839969998636301
# 이미지 2778: Dominant Color: [175, 145, 146], Ratio: 0.4633268249486467
# 이미지 2779: Dominant Color: [30, 30, 31], Ratio: 0.8820441179784142
# 이미지 2780: Dominant Color: [165, 174, 189], Ratio: 0.4833866138935404
# 이미지 2781: Dominant Color: [197, 141, 131], Ratio: 0.7956862374929206
# 이미지 2782: Dominant Color: [20, 20, 22], Ratio: 0.9703827001124833
# 이미지 2783: Dominant Color: [143, 134, 99], Ratio: 0.7213443055907791
# 이미지 2784: Dominant Color: [52, 46, 49], Ratio: 0.3661601417026893
# 이미지 2785: Dominant Color: [55, 53, 52], Ratio: 0.7817638266068759
# 이미지 2786: Dominant Color: [148, 155, 148], Ratio: 0.37462492132496084
# 이미지 2789: Dominant Color: [38, 37, 42], Ratio: 0.8384311530991804
# 이미지 2790: Dominant Color: [38, 38, 38], Ratio: 0.9655126149206815
# 이미지 2791: Dominant Color: [20, 20, 20], Ratio: 0.953202553323992
# 이미지 2792: Dominant Color: [145, 93, 91], Ratio: 0.3616720135874693
# 이미지 2793: Dominant Color: [122, 110, 106], Ratio: 0.41073466139006237
# 이미지 2794: Dominant Color: [213, 205, 188], Ratio: 0.8909301080415998
# 이미지 2795: Dominant Color: [31, 38, 54], Ratio: 0.9536921310651668
# 이미지 2796: Dominant Color: [200, 196, 192], Ratio: 0.5876070333310128
# 이미지 2797: Dominant Color: [17, 26, 30], Ratio: 0.835467844327905
# 이미지 2798: Dominant Color: [125, 136, 145], Ratio: 0.4778881562989261
# 이미지 2799: Dominant Color: [196, 197, 206], Ratio: 0.5755013763271726
# 이미지 2800: Dominant Color: [228, 197, 178], Ratio: 0.6385152458196947
# 이미지 2801: Dominant Color: [221, 214, 194], Ratio: 0.8600745180085188
# 이미지 2802: Dominant Color: [14, 14, 16], Ratio: 0.6842456935186845
# 이미지 2803: Dominant Color: [41, 46, 45], Ratio: 0.5129761126894794
# 이미지 2804: Dominant Color: [22, 19, 21], Ratio: 0.5622909184958428
# 이미지 2805: Dominant Color: [57, 31, 18], Ratio: 0.6893286694973906
# 이미지 2806: Dominant Color: [13, 16, 24], Ratio: 0.7703701496983689
# 이미지 2807: Dominant Color: [29, 29, 31], Ratio: 0.6432852204193898
# 이미지 2808: Dominant Color: [40, 37, 32], Ratio: 0.6500542258316729
# 이미지 2810: Dominant Color: [208, 185, 157], Ratio: 0.38793006434980104
# 이미지 2811: Dominant Color: [183, 179, 172], Ratio: 0.8462417255647934
# 이미지 2812: Dominant Color: [22, 21, 21], Ratio: 0.624219902676845
# 이미지 2813: Dominant Color: [32, 33, 34], Ratio: 0.6653604845537633
# 이미지 2814: Dominant Color: [84, 77, 76], Ratio: 0.634410607205598
# 이미지 2815: Dominant Color: [203, 202, 202], Ratio: 0.44889067582879494
# 이미지 2816: Dominant Color: [38, 39, 53], Ratio: 0.5027827781539529
# 이미지 2817: Dominant Color: [16, 19, 24], Ratio: 0.5401564491572025
# 이미지 2818: Dominant Color: [16, 23, 21], Ratio: 0.762344749087744
# 이미지 2819: Dominant Color: [25, 26, 29], Ratio: 0.7453901788683883
# 이미지 2821: Dominant Color: [113, 40, 51], Ratio: 0.6139626583984902
# 이미지 2822: Dominant Color: [246, 240, 235], Ratio: 0.6558649352788192
# 이미지 2823: Dominant Color: [242, 239, 226], Ratio: 0.6084518492654531
# 이미지 2825: Dominant Color: [228, 230, 237], Ratio: 0.5482778353465209
# 이미지 2826: Dominant Color: [182, 190, 206], Ratio: 0.5199156588670345
# 이미지 2827: Dominant Color: [163, 187, 203], Ratio: 0.5424949166378381
# 이미지 2829: Dominant Color: [24, 24, 28], Ratio: 0.8019922065270336
# 이미지 2830: Dominant Color: [12, 19, 23], Ratio: 0.6296133342446092
# 이미지 2831: Dominant Color: [24, 36, 51], Ratio: 0.7234767099615106
# 이미지 2832: Dominant Color: [215, 215, 212], Ratio: 0.5476158847396128
# 이미지 2834: Dominant Color: [112, 66, 48], Ratio: 0.5333704890622822
# 이미지 2835: Dominant Color: [227, 221, 219], Ratio: 0.5901511853825818
# 이미지 2837: Dominant Color: [19, 21, 23], Ratio: 0.7669063917637791
# 이미지 2840: Dominant Color: [34, 30, 26], Ratio: 0.407151896401322
# 이미지 2842: Dominant Color: [214, 222, 231], Ratio: 0.7892970181138691
# 이미지 2843: Dominant Color: [46, 45, 46], Ratio: 0.7170647422644965
# 이미지 2844: Dominant Color: [167, 10, 54], Ratio: 0.6892810339613432
# 이미지 2845: Dominant Color: [152, 110, 70], Ratio: 0.854464296815746
# 이미지 2846: Dominant Color: [30, 34, 39], Ratio: 0.4562674170624187
# 이미지 2848: Dominant Color: [159, 97, 68], Ratio: 0.4125306751383948
# 이미지 2849: Dominant Color: [19, 30, 34], Ratio: 0.5049280297075809
# 이미지 2850: Dominant Color: [47, 52, 59], Ratio: 0.8632696844929681
# 이미지 2851: Dominant Color: [216, 216, 216], Ratio: 0.4528865796966236
# 이미지 2852: Dominant Color: [203, 196, 184], Ratio: 0.644418974284285
# 이미지 2853: Dominant Color: [22, 22, 23], Ratio: 0.9550769819782864
# 이미지 2855: Dominant Color: [23, 24, 23], Ratio: 0.8293402184505955
# 이미지 2856: Dominant Color: [32, 42, 50], Ratio: 0.4810884602664152
# 이미지 2857: Dominant Color: [61, 62, 66], Ratio: 0.4812170182114279
# 이미지 2859: Dominant Color: [162, 159, 165], Ratio: 0.49202120278633477
# 이미지 2860: Dominant Color: [11, 15, 17], Ratio: 0.5496459540570069
# 이미지 2861: Dominant Color: [229, 228, 234], Ratio: 0.7699658611327652
# 이미지 2862: Dominant Color: [53, 56, 66], Ratio: 0.5536894751554438
# 이미지 2863: Dominant Color: [26, 33, 38], Ratio: 0.7233182101494441
# 이미지 2864: Dominant Color: [173, 168, 135], Ratio: 0.466137325895437
# 이미지 2865: Dominant Color: [239, 239, 239], Ratio: 0.6807639654966174
# 이미지 2866: Dominant Color: [246, 246, 245], Ratio: 0.8957154218112371
# 이미지 2868: Dominant Color: [62, 78, 104], Ratio: 0.6203714650524922
# 이미지 2869: Dominant Color: [192, 196, 217], Ratio: 0.5287222366100608
# 이미지 2870: Dominant Color: [10, 10, 12], Ratio: 0.9298531810766721
# 이미지 2871: Dominant Color: [92, 194, 129], Ratio: 0.41333764623429836
# 이미지 2872: Dominant Color: [21, 30, 48], Ratio: 0.6006776514507879
# 이미지 2873: Dominant Color: [30, 28, 29], Ratio: 0.9532871814516864
# 이미지 2874: Dominant Color: [12, 26, 48], Ratio: 0.8633915359573838
# 이미지 2875: Dominant Color: [157, 171, 176], Ratio: 0.41812887178208147
# 이미지 2876: Dominant Color: [20, 21, 24], Ratio: 0.7200773481710381
# 이미지 2877: Dominant Color: [208, 159, 66], Ratio: 0.83566214718893
# 이미지 2878: Dominant Color: [23, 22, 28], Ratio: 0.8475700760559749
# 이미지 2881: Dominant Color: [24, 34, 41], Ratio: 0.5754429988140866
# 이미지 2882: Dominant Color: [120, 83, 62], Ratio: 0.7209752377663631
# 이미지 2883: Dominant Color: [31, 31, 31], Ratio: 0.7623417258045189
# 이미지 2887: Dominant Color: [16, 18, 27], Ratio: 0.7420668695371677
# 이미지 2888: Dominant Color: [48, 48, 48], Ratio: 0.5264867628536868
# 이미지 2889: Dominant Color: [88, 96, 83], Ratio: 0.5408557724272214
# 이미지 2890: Dominant Color: [35, 44, 45], Ratio: 0.7057809426972104
# 이미지 2893: Dominant Color: [38, 38, 38], Ratio: 0.48955258436071075
# 이미지 2894: Dominant Color: [18, 18, 18], Ratio: 0.6135917819533347
# 이미지 2895: Dominant Color: [25, 22, 47], Ratio: 0.7159418154131437
# 이미지 2896: Dominant Color: [203, 194, 179], Ratio: 0.7984943577790202
# 이미지 2897: Dominant Color: [142, 146, 151], Ratio: 0.5403221264018546
# 이미지 2898: Dominant Color: [39, 39, 40], Ratio: 0.839972411603005
# 이미지 2899: Dominant Color: [23, 21, 29], Ratio: 0.72538165890108
# 이미지 2900: Dominant Color: [11, 37, 57], Ratio: 0.6103683621343393
# 이미지 2902: Dominant Color: [47, 55, 63], Ratio: 0.5343595402573098
# 이미지 2904: Dominant Color: [208, 206, 212], Ratio: 0.43406254421961227
# 이미지 2905: Dominant Color: [31, 28, 30], Ratio: 0.8254922793299374
# 이미지 2907: Dominant Color: [233, 229, 225], Ratio: 0.6171193343214385
# 이미지 2908: Dominant Color: [97, 114, 104], Ratio: 0.951366685020076
# 이미지 2909: Dominant Color: [27, 25, 25], Ratio: 0.7892379626467729
# 이미지 2910: Dominant Color: [58, 65, 74], Ratio: 0.7565392951515691
# 이미지 2911: Dominant Color: [55, 51, 53], Ratio: 0.4956777835346732
# 이미지 2914: Dominant Color: [70, 68, 77], Ratio: 0.5692032781282275
# 이미지 2915: Dominant Color: [184, 168, 151], Ratio: 0.41471224261671696
# 이미지 2916: Dominant Color: [92, 86, 83], Ratio: 0.740269376501872
# 이미지 2917: Dominant Color: [183, 177, 177], Ratio: 0.476229391788358
# 이미지 2918: Dominant Color: [39, 38, 47], Ratio: 0.9348532753131128
# 이미지 2921: Dominant Color: [42, 35, 34], Ratio: 0.46098083685316577
# 이미지 2922: Dominant Color: [13, 18, 20], Ratio: 0.7387314592456562
# 이미지 2923: Dominant Color: [125, 132, 125], Ratio: 0.7038816295157571
# 이미지 2925: Dominant Color: [18, 19, 21], Ratio: 0.7599117037981021
# 이미지 2926: Dominant Color: [171, 176, 188], Ratio: 0.4841961416876765
# 이미지 2927: Dominant Color: [57, 71, 70], Ratio: 0.40053275595644516
# 이미지 2929: Dominant Color: [225, 222, 218], Ratio: 0.44229651314575724
# 이미지 2931: Dominant Color: [77, 77, 79], Ratio: 0.46638539311076166
# 이미지 2932: Dominant Color: [44, 52, 47], Ratio: 0.4941610859862366
# 이미지 2933: Dominant Color: [111, 99, 86], Ratio: 0.9010562770562771
# 이미지 2934: Dominant Color: [20, 20, 22], Ratio: 0.8962943587847192
# 이미지 2940: Dominant Color: [133, 133, 125], Ratio: 0.8167325173376068
# 이미지 2941: Dominant Color: [21, 18, 25], Ratio: 0.49998928927942554
# 이미지 2942: Dominant Color: [228, 233, 234], Ratio: 0.5651932902728237
# 이미지 2943: Dominant Color: [145, 111, 77], Ratio: 0.4146367788556461
# 이미지 2944: Dominant Color: [231, 223, 214], Ratio: 0.7432958461130675
# 이미지 2945: Dominant Color: [25, 26, 32], Ratio: 0.5289280843568467
# 이미지 2946: Dominant Color: [148, 137, 132], Ratio: 0.5236937740891289
# 이미지 2947: Dominant Color: [187, 14, 16], Ratio: 0.5535438338060932
# 이미지 2948: Dominant Color: [250, 251, 252], Ratio: 0.4997369397734827
# 이미지 2950: Dominant Color: [29, 28, 33], Ratio: 0.942630542562051
# 이미지 2951: Dominant Color: [59, 32, 27], Ratio: 0.479991830874344
# 이미지 2952: Dominant Color: [60, 47, 41], Ratio: 0.44262264790120415
# 이미지 2953: Dominant Color: [182, 199, 222], Ratio: 0.6523016836038222
# 이미지 2954: Dominant Color: [28, 28, 26], Ratio: 0.8782350790232804
# 이미지 2955: Dominant Color: [71, 71, 71], Ratio: 0.7117279830382033
# 이미지 2956: Dominant Color: [127, 117, 118], Ratio: 0.4928801583912419
# 이미지 2957: Dominant Color: [51, 51, 53], Ratio: 0.49665279359221015
# 이미지 2958: Dominant Color: [25, 18, 14], Ratio: 0.48416790069288285
# 이미지 2959: Dominant Color: [17, 23, 33], Ratio: 0.6752560441652389
# 이미지 2960: Dominant Color: [12, 21, 22], Ratio: 0.47852458060053504
# 이미지 2962: Dominant Color: [18, 20, 26], Ratio: 0.5661381437109407
# 이미지 2963: Dominant Color: [179, 179, 183], Ratio: 0.484742135284889
# 이미지 2964: Dominant Color: [16, 15, 14], Ratio: 0.8646743995581205
# 이미지 2965: Dominant Color: [38, 39, 59], Ratio: 0.8873869419362691
# 이미지 2967: Dominant Color: [151, 148, 155], Ratio: 0.3550917318313556
# 이미지 2968: Dominant Color: [34, 34, 34], Ratio: 0.7770302403885785
# 이미지 2970: Dominant Color: [37, 35, 38], Ratio: 0.5231543841704543
# 이미지 2971: Dominant Color: [128, 42, 51], Ratio: 0.40484035459323764
# 이미지 2972: Dominant Color: [193, 144, 150], Ratio: 0.408702038852592
# 이미지 2973: Dominant Color: [70, 66, 68], Ratio: 0.4493975308235255
# 이미지 2974: Dominant Color: [26, 27, 27], Ratio: 0.6763888579304401
# 이미지 2975: Dominant Color: [184, 177, 185], Ratio: 0.4323522187062002
# 이미지 2976: Dominant Color: [177, 166, 153], Ratio: 0.4286507572917968
# 이미지 2977: Dominant Color: [231, 230, 229], Ratio: 0.493056556441529
# 이미지 2978: Dominant Color: [103, 58, 64], Ratio: 0.4105992642533813
# 이미지 2979: Dominant Color: [136, 97, 63], Ratio: 0.5948975162526251
# 이미지 2980: Dominant Color: [45, 61, 83], Ratio: 0.5805977512918387
# 이미지 2981: Dominant Color: [25, 24, 27], Ratio: 0.8929968577666166
# 이미지 2982: Dominant Color: [206, 199, 204], Ratio: 0.6472463943124099
# 이미지 2983: Dominant Color: [27, 26, 32], Ratio: 0.8861213712905355
# 이미지 2984: Dominant Color: [31, 30, 29], Ratio: 0.9272151742216287
# 이미지 2985: Dominant Color: [228, 222, 205], Ratio: 0.8804328039584517
# 이미지 2986: Dominant Color: [144, 54, 38], Ratio: 0.399411091852688
# 이미지 2987: Dominant Color: [105, 143, 134], Ratio: 0.5921558225811517
# 이미지 2988: Dominant Color: [140, 124, 102], Ratio: 0.4476784560723514
# 이미지 2989: Dominant Color: [158, 140, 127], Ratio: 0.44219943373868154
# 이미지 2990: Dominant Color: [33, 31, 35], Ratio: 0.6265158643040092
# 이미지 2991: Dominant Color: [103, 99, 103], Ratio: 0.711479805331567
# 이미지 2992: Dominant Color: [206, 198, 176], Ratio: 0.6201629573071116
# 이미지 2994: Dominant Color: [21, 20, 24], Ratio: 0.6118159717444154
# 이미지 2996: Dominant Color: [207, 200, 202], Ratio: 0.5751663332247708
# 이미지 2997: Dominant Color: [25, 25, 25], Ratio: 0.48776521770138714
# 이미지 2998: Dominant Color: [232, 224, 215], Ratio: 0.5133588241752471
# 이미지 2999: Dominant Color: [33, 30, 31], Ratio: 0.9572486956326812

# %% [markdown]
# - 데이터 병합

# %%
data_link = data[["브랜드명", "상품명", "이미지링크"]]
data_link.head()
# Out:
#     브랜드명                           상품명  \
# 0   엠더바스   reach out 오버핏 스웨트셔츠 -메란지그레이
# 1  넷소셜클럽  SMALL CURLY LOGO MTM (BLACK)
# 2  세인트크루     체스트 화이트캣 스웨트셔츠 CCS-809 블랙
# 3  세인트크루    체스트 블랙아치 스웨트셔츠 CCS-809 그레이
# 4    지크립           NEW YORKLIP 특양면 맨투맨
#
#                                                이미지링크
# 0  https://image.msscdn.net/thumbnails/images/goo...
# 1  https://image.msscdn.net/thumbnails/images/goo...
# 2  https://image.msscdn.net/thumbnails/images/goo...
# 3  https://image.msscdn.net/thumbnails/images/goo...
# 4  https://image.msscdn.net/thumbnails/images/goo...

# %%
merged_df = pd.merge(processed_dataset, data_link, on=["브랜드명", "상품명"], how="left")
print(merged_df.head())
# Out:
#    대분류         소분류  성별   계절    브랜드명                            상품명  \
# 0   바지  트레이닝/조거 팬츠  남성   여름  엔피스튜디오               코튼 와이드 스웨트 팬츠 블랙
# 1   상의     셔츠/블라우스  남성    봄  필루미네이트  [유튜버 니들 착용] 오버핏 포레스트 체크 셔츠-블랙
# 2  아우터       무스탕/퍼  남성  NaN     엘무드   A2 에비에이터 카우 하이드 무스탕 자켓 탠 브라운
# 3  아우터     플리스/뽀글이  여성  NaN    피도디도        Fleece Zip Hoodie Black
# 4  스커트       미니스커트  여성   가을  로맨틱크라운              샤이닝 로고 플리츠 스커트_블랙
#
#                                              이미지링크_x   dominant_color  \
# 0  [[[227, 228, 222], [227, 228, 222], [227, 228,...     [27, 31, 33]
# 1  [[[255, 255, 255], [255, 255, 255], [255, 255,...     [35, 35, 35]
# 2  [[[90, 89, 85], [87, 86, 82], [87, 86, 82], [8...     [41, 33, 29]
# 3  [[[241, 241, 241], [241, 241, 241], [241, 241,...     [21, 22, 27]
# 4  [[[206, 200, 204], [206, 200, 204], [205, 199,...  [169, 136, 110]
#
#    dominant_ratio personal_color  \
# 0        0.924865    Winter Cool
# 1        0.592077    Autumn Warm
# 2        0.522527    Autumn Warm
# 3        0.602018    Winter Cool
# 4        0.613097    Spring Warm
#
#                                              이미지링크_y
# 0  https://image.msscdn.net/thumbnails/images/goo...
# 1  https://image.msscdn.net/thumbnails/images/goo...
# 2  https://image.msscdn.net/thumbnails/images/goo...
# 3  https://image.msscdn.net/thumbnails/images/goo...
# 4  https://image.msscdn.net/thumbnails/images/goo...

# %%
merged_df.columns
# Out:
# Index(['대분류', '소분류', '성별', '계절', '브랜드명', '상품명', '이미지링크_x', 'dominant_color',
#        'dominant_ratio', 'personal_color', '이미지링크_y'],
#       dtype='object')

# %%
result = merged_df.drop(columns=['이미지링크_x', 'dominant_color', 'dominant_ratio'], axis=1)
result.head()
# Out:
#    대분류         소분류  성별   계절    브랜드명                            상품명  \
# 0   바지  트레이닝/조거 팬츠  남성   여름  엔피스튜디오               코튼 와이드 스웨트 팬츠 블랙
# 1   상의     셔츠/블라우스  남성    봄  필루미네이트  [유튜버 니들 착용] 오버핏 포레스트 체크 셔츠-블랙
# 2  아우터       무스탕/퍼  남성  NaN     엘무드   A2 에비에이터 카우 하이드 무스탕 자켓 탠 브라운
# 3  아우터     플리스/뽀글이  여성  NaN    피도디도        Fleece Zip Hoodie Black
# 4  스커트       미니스커트  여성   가을  로맨틱크라운              샤이닝 로고 플리츠 스커트_블랙
#
#   personal_color                                            이미지링크_y
# 0    Winter Cool  https://image.msscdn.net/thumbnails/images/goo...
# 1    Autumn Warm  https://image.msscdn.net/thumbnails/images/goo...
# 2    Autumn Warm  https://image.msscdn.net/thumbnails/images/goo...
# 3    Winter Cool  https://image.msscdn.net/thumbnails/images/goo...
# 4    Spring Warm  https://image.msscdn.net/thumbnails/images/goo...

# %%
result = result.rename(columns={'이미지링크_y':'이미지링크'})
result.head()
# Out:
#    대분류         소분류  성별   계절    브랜드명                            상품명  \
# 0   바지  트레이닝/조거 팬츠  남성   여름  엔피스튜디오               코튼 와이드 스웨트 팬츠 블랙
# 1   상의     셔츠/블라우스  남성    봄  필루미네이트  [유튜버 니들 착용] 오버핏 포레스트 체크 셔츠-블랙
# 2  아우터       무스탕/퍼  남성  NaN     엘무드   A2 에비에이터 카우 하이드 무스탕 자켓 탠 브라운
# 3  아우터     플리스/뽀글이  여성  NaN    피도디도        Fleece Zip Hoodie Black
# 4  스커트       미니스커트  여성   가을  로맨틱크라운              샤이닝 로고 플리츠 스커트_블랙
#
#   personal_color                                              이미지링크
# 0    Winter Cool  https://image.msscdn.net/thumbnails/images/goo...
# 1    Autumn Warm  https://image.msscdn.net/thumbnails/images/goo...
# 2    Autumn Warm  https://image.msscdn.net/thumbnails/images/goo...
# 3    Winter Cool  https://image.msscdn.net/thumbnails/images/goo...
# 4    Spring Warm  https://image.msscdn.net/thumbnails/images/goo...

# %%
result.to_csv('fashion_data.csv', index=False)
